# %%
# this file is for dream1 data, with MEDIUM clusters generated using the ic_50 parameter (spectral clustering)
# we add proteins back if they connect > Half of all components in the cluster

# %%
# importing libraries

# standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# library used for functional enrichment analysis
from func_e.FUNC_E import FUNC_E  # a method that can do funtional enrichment analysis!
import func_e.vocabs.all as vocabs

# %%
# following code is necessary as some functions used in the funcE class produce future warnings but i can't fix it as it is not my code
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# importing the custom classes i built
from matrix_class import ProteinMatrix # ppi matrix 
from cluster_class import AllClusters # dictionary to hold all clusters (in form number of cluster : list of proteins in that cluster)
from degreelist_class import DegreeList # creates a list of all proteins in order of their degree

# %%
# helper functions for setting up program
from recipe_utils import initialize_matrix_clusters_degreelist
from recipe_utils import find_clusters_and_proteins_together

# helper functions for functional enrichment
from recipe_utils import print_querylist_of_clusters_to_file
from recipe_utils import print_protein_background_to_file
from recipe_utils import create_term_mapping_list
from recipe_utils import get_initialized_fe

# %%
matrix, clusters, degreelist = initialize_matrix_clusters_degreelist(interactions_filepath="data/interactions/1_ppi_string_v2.txt", clusters_filepath="data/ic_50_medium/dream1_medium-cluster.json")

# %%
#qualifying_clusters, qualifying_proteins = find_clusters_and_proteins_together(matrix, clusters, degreelist, cluster_ratio=0, cluster_constant=2,use_sqrt=True, protein_ratio=.5, protein_constant=0)
qualifying_clusters, qualifying_proteins = find_clusters_and_proteins_together(matrix, clusters, degreelist, cluster_ratio=0, cluster_constant=2,use_sqrt=False, protein_ratio=0.5, protein_constant=0)

# %%
qualifying_proteins
# Out:
# {0: ['PDE4DIP',
#   'WDR1',
#   'AP2A2',
#   'CCNL1',
#   'USP34',
#   'AP2A1',
#   'MAGI1',
#   'HECTD3',
#   'KIAA0317',
#   'PFDN4',
#   'ARRB1',
#   'SEC13',
#   'BCCIP',
#   'PRPF4',
#   'RNF40'],
#  5: ['NLRP4',
#   'RIN1',
#   'RABGGTA',
#   'LRPAP1',
#   'RAP1GAP',
#   'SAFB2',
#   'ZBP1',
#   'SCMH1',
#   'RCAN2',
#   'RCAN3',
#   'SCML2',
#   'FADD',
#   'TGM2',
#   'APTX',
#   'RCAN1',
#   'PHF16',
#   'IRF3',
#   'PHF15',
#   'INHBB',
#   'RNMT',
#   'PHF17',
#   'MLLT4',
#   'DCPS',
#   'CHURC1-FNTB',
#   'ARR3',
#   'SMTNL2',
#   'CHML',
#   'FNTB',
#   'CENPF',
#   'SPECC1L',
#   'SPECC1',
#   'SMTNL1',
#   'SMTN',
#   'MAGIX',
#   'CASP8',
#   'SNCA',
#   'WWC2',
#   'CHM',
#   'ACVR1',
#   'TBK1',
#   'HMGCR',
#   'VAV2',
#   'MED7',
#   'GDI1',
#   'WWC1',
#   'PAPOLB',
#   'PAPOLG',
#   'UBE3B',
#   'UBE3C',
#   'STAT2',
#   'SPATA13',
#   'PDK1',
#   'MAGI1',
#   'TAF10',
#   'CASP3',
#   'HECTD3',
#   'HECTD1',
#   'KIAA0317',
#   'PAPOLA',
#   'TGFBR1',
#   'ARRB1',
#   'BTF3L4',
#   'PDPK1',
#   'TGFB1',
#   'CRNKL1',
#   'GDI2',
#   'MAGI3',
#   'DQX1',
#   'DHX32',
#   'HECTD2',
#   'UBR5',
#   'EXOSC2',
#   'ACAT1',
#   'DHX35',
#   'HECW1',
#   'HINT1',
#   'NKPD1',
#   'PSMD14',
#   'DHX16'],
#  30: ['TCEB2',
#   'PPP6R2',
#   'PPP6R1',
#   'CTU2',
#   'PPP6R3',
#   'NOM1',
#   'CTDP1',
#   'GAMT',
#   'WDR61',
#   'NOP9',
#   'CECR1',
#   'ADA',
#   'PUS7L',
#   'FAM203B',
#   'ADAL',
#   'FAM203A',
#   'PUS7',
#   'TRMT11',
#   'ZNF622',
#   'WDR75',
#   'CCNT1',
#   'WDR4',
#   'DDX31',
#   'AATF',
#   'DQX1',
#   'DHX32',
#   'ESF1',
#   'DHX34',
#   'RRP8',
#   'MYBBP1A',
#   'DHX40',
#   'DHX33',
#   'CIRH1A',
#   'NOC4L',
#   'UTP14C',
#   'FTSJ2',
#   'TRMT1L',
#   'DHX35',
#   'RBM28',
#   'NOL6',
#   'MPHOSPH10',
#   'TTC27',
#   'WDR43',
#   'UBFD1',
#   'NOB1',
#   'DHX16',
#   'IKBKAP',
#   'STAT1',
#   'TRMT1',
#   'PAK1IP1',
#   'LTV1',
#   'SNRPB2',
#   'UTP14A',
#   'RNF40',
#   'RBM19',
#   'NOP14',
#   'GNL1',
#   'DDX52',
#   'UTP6',
#   'MAK16'],
#  33: ['TPRKB',
#   'ARPC1A',
#   'FUBP1',
#   'SH3GL1',
#   'WDR1',
#   'ARPC5L',
#   'ARPC3',
#   'LPP',
#   'ARPC5',
#   'NWD1',
#   'CAPZB',
#   'KIAA1239',
#   'WDR20',
#   'ARPC2',
#   'HIP1',
#   'HIP1R',
#   'CAPZA3',
#   'PFN2',
#   'WASL',
#   'CAPZA2',
#   'ACTR6',
#   'CFL2',
#   'PFN1',
#   'CAPZA1',
#   'MYO16',
#   'PSMA7',
#   'WDFY2'],
#  48: ['MARCH1',
#   'ELOVL1',
#   'MARCH6',
#   'NGLY1',
#   'OTUD6B',
#   'EDF1',
#   'AHSA2',
#   'FBP2',
#   'SUGT1P3',
#   'FBP1',
#   'TTC12',
#   'AHSA1',
#   'DNAJC24',
#   'TTC31',
#   'DNAJC16',
#   'PPIL6',
#   'PSMD8',
#   'PSMD11',
#   'PSMA8',
#   'COPS2',
#   'PTGES3L',
#   'IQCA1',
#   'DNAJA3',
#   'DNAJB13',
#   'DNAJB5',
#   'DNAJB4',
#   'FIGN',
#   'PSMB4',
#   'PPID',
#   'UBFD1',
#   'NKTR',
#   'FIGNL1',
#   'PPIH',
#   'PPIG',
#   'ATAD1',
#   'PSMA7',
#   'SPAST',
#   'STIP1'],
#  50: ['NMRK1',
#   'NMRK2',
#   'CAB39L',
#   'CAB39',
#   'GPCPD1',
#   'DLK2',
#   'PDZD2',
#   'DLG5',
#   'INADL',
#   'CAPZA3',
#   'RASGEF1B',
#   'GINS1',
#   'CAPZA2',
#   'MIB2',
#   'CAPZA1'],
#  53: ['MPND'],
#  75: ['C12orf65', 'MTRF1L', 'CLPP'],
#  79: ['LHX3',
#   'LHX4',
#   'GCM2',
#   'SSBP4',
#   'GCM1',
#   'SSBP2',
#   'SSBP3',
#   'RFNG',
#   'LDB2',
#   'LFNG',
#   'MFNG',
#   'LDB1',
#   'WRB',
#   'TBX4',
#   'TBR1',
#   'TBX6',
#   'TBX19',
#   'T',
#   'EYS',
#   'TBX2',
#   'EOMES',
#   'MGA',
#   'TBX5',
#   'TBX21',
#   'TBX3',
#   'ASNA1',
#   'POTEB',
#   'NKPD1',
#   'POTEG',
#   'ANKRD35',
#   'POTEM',
#   'CASKIN1',
#   'POTEC',
#   'ANKRD24',
#   'ABTB1',
#   'KANK3',
#   'FPGT-TNNI3K'],
#  81: ['ARL15',
#   'GRIN1',
#   'C9orf69',
#   'SEPT7L',
#   'PTPRZ1',
#   'SEPT14',
#   'PTPRS',
#   'SEPT10',
#   'SEPT8',
#   'ARF6',
#   'SEPT11',
#   'PTPRD',
#   'SEPT1',
#   'SEPT6',
#   'RASGEF1B',
#   'SEPT4',
#   'PTPRF',
#   'SEPT5',
#   'PTPRG',
#   'CIRH1A',
#   'SEPT7'],
#  84: ['CXCL13', 'AVP', 'GRK5'],
#  88: ['CCL4L2',
#   'CCBP2',
#   'C1QC',
#   'CCL4L1',
#   'CX3CR1',
#   'IGFBP7',
#   'IL1A',
#   'CCL4',
#   'RSAD2',
#   'IL1B',
#   'IL6',
#   'XCR1',
#   'CXCL16',
#   'IRF1',
#   'CXCL6',
#   'CXCL5',
#   'CXCL3',
#   'CXCL2',
#   'CXCL1',
#   'CCL20',
#   'CCR9',
#   'CXCR6',
#   'CCR10',
#   'CCR8',
#   'CCR6',
#   'CCR2',
#   'CCR7',
#   'CXCR3',
#   'CCR4',
#   'CXCR1',
#   'CXCR5',
#   'CCR3',
#   'CXCR2',
#   'CCR1',
#   'BCL2A1',
#   'CXCL10',
#   'CCR5',
#   'CXCR4',
#   'IL8'],
#  96: ['C9orf9',
#   'GRK6',
#   'TRPV4',
#   'CD2AP',
#   'BCL10',
#   'ITGA2B',
#   'SERPINH1',
#   'AXIN2',
#   'ADRBK1',
#   'TCEB2',
#   'ACVR1B',
#   'AXIN1',
#   'GRK5',
#   'FN1',
#   'CAMK2B',
#   'CAMK2A',
#   'ARF6',
#   'ADRBK2',
#   'LDHAL6B',
#   'APC',
#   'PLCG1',
#   'NCK1',
#   'ATP6V1B1'],
#  117: ['RCE1',
#   'DIAPH2',
#   'RASAL3',
#   'TRAPPC10',
#   'DIAPH3',
#   'MCF2L2',
#   'PGGT1B',
#   'SYNGAP1',
#   'PARD6G',
#   'DIAPH1',
#   'RASAL2',
#   'RABIF',
#   'PARD6B',
#   'CHURC1-FNTB',
#   'DAB2IP',
#   'CYFIP1',
#   'CYFIP2',
#   'ICMT',
#   'YIPF7',
#   'IQSEC3',
#   'SGSM2',
#   'IQSEC2',
#   'CHML',
#   'PSD3',
#   'ARHGAP27',
#   'TBC1D13',
#   'FNTB',
#   'YIPF5',
#   'RABGGTB',
#   'AP4E1',
#   'PSD4',
#   'TBC1D16',
#   'PSD2',
#   'IQSEC1',
#   'YIPF6',
#   'SGSM1',
#   'AGAP3',
#   'OMA1',
#   'AGAP8',
#   'AGAP7',
#   'AGAP6',
#   'AGAP1',
#   'AGAP9',
#   'AGAP5',
#   'TBC1D28',
#   'TBC1D3G',
#   'TBC1D3F',
#   'TBC1D3C',
#   'PSD',
#   'TBC1D26',
#   'SGSM3',
#   'TBC1D3H',
#   'TBC1D3B',
#   'TBC1D29',
#   'AGAP4',
#   'TOM1L2',
#   'TBC1D8B',
#   'EXOC8',
#   'ARHGAP31',
#   'TBC1D9B',
#   'TBC1D8',
#   'TBC1D5',
#   'TBC1D14',
#   'ARHGAP9',
#   'ARHGEF35',
#   'TBC1D12',
#   'KSR2',
#   'TOM1',
#   'CYTH4',
#   'ARHGEF19',
#   'ACAP3',
#   'ISYNA1',
#   'ARFRP1',
#   'TBC1D3',
#   'CHM',
#   'ASAP3',
#   'TBC1D21',
#   'TBC1D9',
#   'RABAC1',
#   'AGAP2',
#   'ARHGAP15',
#   'AP1G2',
#   'ARHGAP36',
#   'AP5M1',
#   'ACAP2',
#   'AP4M1',
#   'ACAP1',
#   'ARHGEF15',
#   'ARHGDIG',
#   'TBC1D25',
#   'EXOC7',
#   'TOM1L1',
#   'RABGAP1L',
#   'KSR1',
#   'GOSR2',
#   'ARHGEF26',
#   'ARAP2',
#   'AP1G1',
#   'MCF2',
#   'EXOC6B',
#   'ARHGEF5',
#   'ARHGAP6',
#   'BET1L',
#   'ASAP2',
#   'ARAP3',
#   'CYTH3',
#   'EXOC2',
#   'BET1',
#   'TBC1D17',
#   'PARD6A',
#   'ARHGDIB',
#   'RABGAP1',
#   'EXOC6',
#   'USP6NL',
#   'GDI1',
#   'ARAP1',
#   'AP1M2',
#   'EXOC4',
#   'TSC1',
#   'FBXO8',
#   'CYTH2',
#   'TBC1D15',
#   'ZMPSTE24',
#   'RALBP1',
#   'HMHA1',
#   'GBF1',
#   'GGA3',
#   'GGA2',
#   'GGA1',
#   'SMAP1',
#   'RASA1',
#   'ASAP1',
#   'SPATA13',
#   'RAB17',
#   'ARHGAP29',
#   'RAB22A',
#   'ADAP2',
#   'CYTH1',
#   'TBC1D22A',
#   'STX5',
#   'RABL6',
#   'CHN2',
#   'SMAP2',
#   'ARFGAP2',
#   'AP1M1',
#   'AGFG1',
#   'RAB19',
#   'TBC1D22B',
#   'ADAP1',
#   'CHN1',
#   'RAB43',
#   'RAB5C',
#   'RAB3IL1',
#   'RAB31',
#   'NGEF',
#   'RAB24',
#   'ARHGEF16',
#   'ARCN1',
#   'AP4B1',
#   'ARHGEF11',
#   'RAB33A',
#   'ARHGEF1',
#   'ARHGDIA',
#   'COPG2',
#   'RAB5B',
#   'BRAF',
#   'RAB3IP',
#   'RAB33B',
#   'RAB20',
#   'ARFGAP3',
#   'TBC1D30',
#   'STX19',
#   'PLD6',
#   'ARAF',
#   'ARHGAP11B',
#   'PGM2L1',
#   'GRTP1',
#   'AKAP13',
#   'AP3B2',
#   'ARHGAP11A',
#   'KLHDC9',
#   'TBC1D2',
#   'ARHGEF12',
#   'USP6',
#   'ARFGEF1',
#   'FBXO42',
#   'RABEPK',
#   'TBC1D2B',
#   'PFN4',
#   'IQGAP2',
#   'ARFGAP1',
#   'STX11',
#   'KLHDC1',
#   'COPG1',
#   'KLHDC2',
#   'PGM2',
#   'VAMP5',
#   'RAB1B',
#   'STX3',
#   'MT-CO2',
#   'KLHDC3',
#   'IQGAP3',
#   'AP3B1',
#   'STX4',
#   'RAB9B',
#   'VAMP4',
#   'PGS1',
#   'COPB2',
#   'AP1B1',
#   'VAMP8',
#   'NCF4',
#   'GDI2',
#   'SH3PXD2B',
#   'AP2M1',
#   'STX2',
#   'KLHDC10',
#   'KALRN',
#   'YKT6',
#   'STX1B',
#   'PFN2',
#   'SEC22C',
#   'NET1',
#   'ARHGEF3',
#   'CIB3',
#   'ARFGEF2',
#   'SH3PXD2A',
#   'VAMP1',
#   'RAB44',
#   'RAB9A',
#   'RASEF',
#   'SEC22A',
#   'RAB40C',
#   'RAB40A',
#   'RAB1A',
#   'RAB40B',
#   'RAB12',
#   'CIB2',
#   'RAB40AL',
#   'GUCA1B',
#   'GUCA1C',
#   'EFCAB1',
#   'VAMP3',
#   'STX1A',
#   'RAB15',
#   'KIF12',
#   'AP2B1',
#   'KIF24',
#   'RAB28',
#   'KCNIP1',
#   'RAB8B',
#   'KIF6',
#   'RAB13',
#   'NCS1',
#   'RAB5A',
#   'GUCA1A',
#   'PFN1',
#   'KCNIP2',
#   'VAMP7',
#   'PGM3',
#   'HPCAL4',
#   'KIF26B',
#   'MYO16',
#   'PIP5KL1',
#   'KCNIP4',
#   'KCNIP3',
#   'TSNARE1',
#   'STARD9',
#   'RAB10',
#   'KIF9',
#   'CLHC1',
#   'VSNL1',
#   'KIF16B',
#   'KIF13A',
#   'RCVRN',
#   'STX16-NPEPL1',
#   'KIF26A',
#   'IQGAP1',
#   'PI4KB',
#   'STX17',
#   'STX16',
#   'MYL6B',
#   'KIF13B',
#   'PIP4K2C'],
#  119: ['DNAJC21',
#   'SSU72',
#   'PDCD4',
#   'GET4',
#   'DIDO1',
#   'CTDNEP1',
#   'CDC37L1',
#   'THOC2',
#   'MOV10L1',
#   'CCND3',
#   'ZNFX1',
#   'MRGBP',
#   'CTDP1',
#   'DDX19A',
#   'DOT1L',
#   'DDX25',
#   'HELZ',
#   'ASH2L',
#   'IGHMBP2',
#   'DDX19B',
#   'CSTF2T',
#   'RBBP5',
#   'SRSF2',
#   'TERF1',
#   'TIMM50',
#   'PIAS3',
#   'MOV10',
#   'C9orf114',
#   'BCL2L2-PABPN1',
#   'TFIP11',
#   'PIN4',
#   'PRPF40A',
#   'SETX',
#   'EIF4G3',
#   'TCEANC',
#   'VPS72',
#   'PFDN2',
#   'ZNHIT1',
#   'TCEANC2',
#   'CCNT1',
#   'CSTF2',
#   'CPSF2',
#   'CCND1',
#   'CCNE1',
#   'DNA2',
#   'CDC37',
#   'PIAS4',
#   'DDX31',
#   'POLDIP3',
#   'DDX55',
#   'CCNC',
#   'PIAS2',
#   'CDC25B',
#   'FTSJ1',
#   'POLR3K',
#   'BCCIP',
#   'FTSJ2',
#   'TRMT1L',
#   'ABCC8',
#   'UBFD1',
#   'TCEA3',
#   'PIAS1',
#   'PPIL4',
#   'KRI1',
#   'IKBKAP',
#   'UBE2J1',
#   'MORF4L2',
#   'CDC25C',
#   'CDC7',
#   'SSBP1',
#   'MAK16'],
#  127: ['KLHL17', 'KLHL18', 'KLHL20', 'NR1H3', 'NR1H2', 'LHX5', 'LHX1']}

# %%
# use functions to print info to files: (annoying, but need to get info into format used for funcE package)


# 1) a background protein list to be used for functional enrichment analysis
background_proteins_filepath = "data/ic_50/background_proteinlist.txt"
print_protein_background_to_file(matrix, background_proteins_filepath)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 6
#       1 # use functions to print info to files: (annoying, but need to get info into format used for funcE package)
#       2
#       3
#       4 # 1) a background protein list to be used for functional enrichment analysis
#       5 background_proteins_filepath = "data/ic_50/background_proteinlist.txt"
# ----> 6 print_protein_background_to_file(matrix, background_proteins_filepath)
#
# File ~/Desktop/Desktop/ReCIPE/recipe_utils.py:53, in print_protein_background_to_file(matrix, filename)
#      51 def print_protein_background_to_file(matrix: ProteinMatrix, filename: str = "background_proteinlist.txt") -> None:
#      52     """ TODO """
# ---> 53     with open(filename, 'w') as file:
#      54         for protein in matrix.get_list_of_proteins():
#      55             file.write(f"{protein}\n")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ic_50/background_proteinlist.txt'

# %%
# 2) file containing protein to go term
term_mapping_filepath = "data/ic_50/term_mapping.txt"
create_term_mapping_list("demo_data/dream3_go_results.tsv", term_mapping_filepath)

# 3) not a file, but need to establish a background of all GO terms! (to be used for functional enrichment analysis)
background_go_terms = vocabs.getTerms(['GO'])

# %%
# continue printing info to files to be used in functional enrichment analysis:

# 4) print original clusters to a file
og_query_filepath = 'demo_data/original_clusters.txt'
print_querylist_of_clusters_to_file(clusters, clusters.get_all_cluster_labels(),og_query_filepath)

# 5) print updated clusters to a file (just append the function to include the dictionary of qualifying proteins)
updated_query_filepath = 'demo_data/updated_clusters.txt'
print_querylist_of_clusters_to_file(clusters, clusters.get_all_cluster_labels(), updated_query_filepath, qualifying_proteins)

# %%
original_fe = get_initialized_fe(background_proteins_filepath, term_mapping_filepath, termlist = background_go_terms)

original_fe.importFiles({'query': og_query_filepath })
original_fe.run(cluster=False)

# %%
# do functional enrichment on updated clusters!!

updated_fe_all_proteins = get_initialized_fe(background_proteins_filepath, term_mapping_filepath, termlist = background_go_terms)

updated_fe_all_proteins.importFiles({'query': updated_query_filepath })
updated_fe_all_proteins.run(cluster=False)

# %%
# print data by the numbers!
print(f"number of clusters that were updated with proteins: {len(qualifying_proteins.keys())}\n")

# clusters that are functionally enriched
print(f"number of functionally enriched clusters (modules) out of {len(qualifying_proteins.keys())} original clusters: {original_fe.enrichment['Module'].nunique()}")
print(f"number of functionally enriched clusters after addition of all proteins: {updated_fe_all_proteins.enrichment['Module'].nunique()}")

print(f"")


# significant P-values!!!
print(f"number of significant pvals in original clusters before updating: {original_fe.enrichment['Fishers_pvalue'].count()}")
print(f"number of significant pvals in clusters with all proteins added: {updated_fe_all_proteins.enrichment['Fishers_pvalue'].count()}")
# Out:
# number of clusters that were updated with proteins: 12
#
# number of functionally enriched clusters (modules) out of 12 original clusters: 155
# number of functionally enriched clusters after addition of all proteins: 155
#
# number of significant pvals in original clusters before updating: 405
# number of significant pvals in clusters with all proteins added: 411
