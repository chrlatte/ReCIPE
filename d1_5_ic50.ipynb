# %%
# this file is for dream1 data, with SMALL clusters generated using the ic_50 parameter (spectral clustering)
# we add proteins back if they connect > half of all components in the cluster

# %%
# importing libraries

# standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# library used for functional enrichment analysis
from func_e.FUNC_E import FUNC_E  # a method that can do funtional enrichment analysis!
import func_e.vocabs.all as vocabs

# %%
# following code is necessary as some functions used in the funcE class produce future warnings but i can't fix it as it is not my code
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# importing the custom classes i built
from matrix_class import ProteinMatrix # ppi matrix 
from cluster_class import AllClusters # dictionary to hold all clusters (in form number of cluster : list of proteins in that cluster)
from degreelist_class import DegreeList # creates a list of all proteins in order of their degree

# %%
# helper functions for setting up program
from recipe_utils import initialize_matrix_clusters_degreelist
from recipe_utils import find_clusters_and_proteins_together

# helper functions for functional enrichment
from recipe_utils import print_querylist_of_clusters_to_file
from recipe_utils import print_protein_background_to_file
from recipe_utils import create_term_mapping_list
from recipe_utils import get_initialized_fe

# %%
matrix, clusters, degreelist = initialize_matrix_clusters_degreelist(interactions_filepath="data/interactions/1_ppi_string_v2.txt", clusters_filepath="data/ic_50/dream1_small-cluster.json")

# %%
#qualifying_clusters, qualifying_proteins = find_clusters_and_proteins_together(matrix, clusters, degreelist, cluster_ratio=0, cluster_constant=2,use_sqrt=True, protein_ratio=.5, protein_constant=0)
qualifying_clusters_5, qualifying_proteins_5 = find_clusters_and_proteins_together(matrix, clusters, degreelist, cluster_ratio=0, cluster_constant=2,use_sqrt=False, protein_ratio=.5, protein_constant=0)

# %%
qualifying_proteins_5
# Out:
# {1: ['ADD3',
#   'ADD2',
#   'ADD1',
#   'APIP',
#   'KYNU',
#   'AOX1',
#   'COQ3',
#   'NT5E',
#   'TTR',
#   'CNDP1',
#   'DPYS',
#   'SORD',
#   'CNDP2',
#   'ADSL',
#   'ALDH1L2',
#   'ALDH1L1',
#   'ALDH1A2',
#   'APRT',
#   'ALDH2',
#   'ALDH1A3',
#   'ALDH1B1',
#   'ALDH1A1',
#   'LDHAL6B'],
#  4: ['EPT1',
#   'CEPT1',
#   'UCK2',
#   'ELOVL7',
#   'KMO',
#   'ELOVL1',
#   'ELOVL2',
#   'ELOVL4',
#   'DHCR7',
#   'FASN',
#   'ELOVL5',
#   'COQ6',
#   'LSS',
#   'GADL1',
#   'AGPAT3',
#   'AGPAT4',
#   'LCLAT1',
#   'SQLE',
#   'PEMT',
#   'CSAD',
#   'AGXT',
#   'AGPAT2',
#   'TSTA3',
#   'SDR42E2',
#   'UXS1',
#   'SDR42E1',
#   'NSDHL',
#   'HSD3B7',
#   'HSD3B2',
#   'HMGCS1',
#   'FDPS',
#   'HSD3B1',
#   'B3GNTL1',
#   'IDH3G',
#   'ALG5',
#   'IDH3B',
#   'PIGA',
#   'DPM1',
#   'IDH3A',
#   'PDHB',
#   'VAPB',
#   'VAPA',
#   'ABCB11'],
#  6: ['ELK4',
#   'ELF1',
#   'CEBPB',
#   'ID2',
#   'ETV6',
#   'KSR2',
#   'KSR1',
#   'BRAF',
#   'ARAF',
#   'MAPK10',
#   'MAPK9'],
#  8: ['NUDT16',
#   'PDE8A',
#   'CANT1',
#   'PDE6D',
#   'QPRT',
#   'TYMP',
#   'DCTPP1',
#   'PDE3A',
#   'PDE6H',
#   'PDE1C',
#   'CDA',
#   'PDE1B',
#   'ENTPD4',
#   'PDE6G',
#   'PDE1A',
#   'NAMPTL',
#   'UPP2',
#   'ENTPD6',
#   'ENTPD5',
#   'UPP1',
#   'PNP',
#   'NAPRT1',
#   'AMPD2',
#   'AMPD3',
#   'ENTPD8',
#   'ENPP3',
#   'ENTPD3',
#   'ENTPD1',
#   'ENPP1',
#   'AMPD1',
#   'NMNAT3',
#   'NMNAT2',
#   'DCTD',
#   'NUDT12',
#   'NMNAT1',
#   'AK5',
#   'CMPK1',
#   'ADK',
#   'AK7',
#   'HPRT1',
#   'AK1',
#   'AK8',
#   'AK4',
#   'ADA',
#   'DCK',
#   'ADSL',
#   'AK2',
#   'APRT',
#   'ADSSL1',
#   'ATIC',
#   'ADSS',
#   'ITPA',
#   'CMPK2'],
#  9: ['TGFA', 'MAGI2', 'GRASP', 'VGLL2', 'SFRP1', 'MAGI3', 'PLCG1'],
#  13: ['BMI1'],
#  57: ['CLEC4M',
#   'MDK',
#   'SPRY3',
#   'MBP',
#   'SLC27A6',
#   'RABGEF1',
#   'ARHGEF2',
#   'GAB2',
#   'ENAH',
#   'GAB1',
#   'MAP3K4',
#   'SPRY2',
#   'GRAP',
#   'PTPN20B',
#   'PTPN20A',
#   'PTPN18',
#   'PTPN7',
#   'PTPRR',
#   'BRAF',
#   'ARAF',
#   'PTPN5',
#   'PTPN22',
#   'PTPN2',
#   'PTPN12',
#   'NCK1',
#   'PTPRG',
#   'PTPN6',
#   'RACGAP1',
#   'STAT3'],
#  58: ['TRIM23'],
#  59: ['MCRS1',
#   'E2F6',
#   'DNMT1',
#   'HIRA',
#   'ING4',
#   'ING2',
#   'ING3',
#   'ING5',
#   'ING1',
#   'CFDP1',
#   'SUPT4H1',
#   'ZNHIT1',
#   'YEATS2',
#   'TOX4',
#   'BAZ1B',
#   'BAZ2B',
#   'BMI1',
#   'DDB1',
#   'YEATS4',
#   'MLLT3'],
#  60: ['KAZN',
#   'ARHGEF40',
#   'PPFIA2',
#   'PLXNB3',
#   'PLXNA3',
#   'PLXNA4',
#   'GRIA1',
#   'PLXNA1',
#   'PLXNB1',
#   'CLSTN3',
#   'GRAPL',
#   'NCK2',
#   'GRAP',
#   'ITGB3',
#   'ITGB2',
#   'GRAP2',
#   'KALRN',
#   'ITGB1',
#   'NCK1'],
#  62: ['MFRP',
#   'CORIN',
#   'SFRP5',
#   'SFRP4',
#   'FZD9',
#   'FZD10',
#   'FZD8',
#   'SMO',
#   'FZD7',
#   'FZD3',
#   'FZD6',
#   'SFRP2',
#   'FRZB',
#   'SFRP1',
#   'FZD1',
#   'FZD5',
#   'FZD2',
#   'FZD4',
#   'FAF2',
#   'HECTD1',
#   'RNF7',
#   'TALDO1',
#   'SLC25A3',
#   'MLST8'],
#  63: ['HINT1'],
#  64: ['PRTFDC1', 'CTU1', 'HPRT1', 'SLMAP'],
#  67: ['AGK',
#   'TRMT12',
#   'PLA2G4F',
#   'PLA2G4E',
#   'PLA2G4D',
#   'PLA2G4B',
#   'JMJD7-PLA2G4B',
#   'CERK',
#   'CERKL',
#   'RTDR1',
#   'ARMC4',
#   'SPHK2',
#   'SPHK1',
#   'CSNK1G3',
#   'CSNK1G1',
#   'CSNK1G2',
#   'TSNARE1',
#   'STX16-NPEPL1',
#   'STX17',
#   'STX16'],
#  68: ['ARHGEF9',
#   'DNMBP',
#   'ARHGAP42',
#   'SORBS2',
#   'ARHGEF4',
#   'SORBS1',
#   'ARHGAP10',
#   'OPHN1',
#   'ARHGAP26',
#   'EXOC7',
#   'EXOC4',
#   'KLHDC9',
#   'FBXO42',
#   'RABEPK',
#   'PFN4',
#   'IQGAP2',
#   'KLHDC1',
#   'KLHDC2',
#   'KLHDC3',
#   'IQGAP3',
#   'KLHDC10',
#   'PFN2',
#   'KIF12',
#   'KIF24',
#   'KIF6',
#   'PFN1',
#   'KIF26B',
#   'MYO16',
#   'PIP5KL1',
#   'STARD9',
#   'KIF9',
#   'KIF16B',
#   'KIF13A',
#   'KIF26A',
#   'IQGAP1',
#   'MYL6B',
#   'KIF13B',
#   'PIP4K2C'],
#  71: ['SCUBE2',
#   'SVEP1',
#   'CFC1',
#   'HGFAC',
#   'DLL3',
#   'ITGA7',
#   'CRB2',
#   'DLL4',
#   'TDGF1',
#   'TLE6',
#   'ITGA6',
#   'JAG2',
#   'DLK1',
#   'EYS',
#   'TLE2',
#   'TLE3',
#   'TLE4',
#   'JAG1',
#   'DLL1',
#   'AES',
#   'TLE1',
#   'POTEB',
#   'NKPD1',
#   'POTEG',
#   'ANKRD35',
#   'POTEM',
#   'CASKIN1',
#   'POTEC',
#   'ANKRD24',
#   'ABTB1',
#   'KANK3',
#   'FPGT-TNNI3K'],
#  73: ['XPO4',
#   'ARIH2',
#   'RBCK1',
#   'NOL11',
#   'RANBP3L',
#   'RNF6',
#   'RANBP3',
#   'ZNF598',
#   'UBR2',
#   'NUP50',
#   'SHFM1',
#   'IRF7',
#   'UBR1',
#   'XPOT',
#   'GTF2A2',
#   'MAGOHB',
#   'MAF1',
#   'GPN3',
#   'MMS19',
#   'HIRA',
#   'LSM4',
#   'RAB5C',
#   'DUS3L',
#   'HECTD3',
#   'NUP153',
#   'KIAA0317',
#   'SUPT4H1',
#   'PSMA6',
#   'TCEANC',
#   'TCEANC2',
#   'RTF1',
#   'PSMA2',
#   'ORC5',
#   'UBR5',
#   'RGPD3',
#   'RGPD8',
#   'RGPD1',
#   'RGPD5',
#   'RGPD6',
#   'PSMB7',
#   'PAF1',
#   'PSMB10',
#   'TCEA3',
#   'RGPD2',
#   'PSMA3',
#   'RNF40',
#   'PSMA7'],
#  76: ['ZNF207',
#   'SREK1',
#   'KHDRBS3',
#   'CPSF4',
#   'TAOK1',
#   'TBL1Y',
#   'KHDRBS2',
#   'CPSF6',
#   'SRSF11',
#   'CPSF7',
#   'TIA1',
#   'HNRNPUL1',
#   'QKI',
#   'SF1',
#   'RBM39',
#   'KHDRBS1',
#   'TARDBP',
#   'STAU1',
#   'PTBP3',
#   'HNRNPH1',
#   'ZC3H14',
#   'TNPO2',
#   'TBL1X',
#   'SRSF2',
#   'RAE1',
#   'EIF2C3',
#   'WDR82',
#   'EIF2C4',
#   'EIF4G3',
#   'KDM5B',
#   'TOP1MT',
#   'TNPO1',
#   'DNA2',
#   'SUZ12',
#   'SNRNP35',
#   'TENC1',
#   'DAZ3',
#   'YBX1',
#   'DAZ2',
#   'RBM3',
#   'BMI1',
#   'DAZ4'],
#  78: ['MYL6B'],
#  79: ['MFSD9',
#   'COG5',
#   'SNIP1',
#   'CDK20',
#   'TADA3',
#   'ING1',
#   'CFDP1',
#   'UBR5',
#   'YEATS2',
#   'ZRANB3',
#   'SHPRH',
#   'SMARCAL1',
#   'YEATS4',
#   'MLLT3'],
#  105: ['NCAPD3',
#   'UHRF2',
#   'NUP160',
#   'ASPM',
#   'NCAPD2',
#   'INCENP',
#   'CHAF1A',
#   'NCAPH',
#   'NUP85',
#   'RACGAP1',
#   'MCM8'],
#  110: ['LCN2',
#   'FSTL1',
#   'VCAN',
#   'LTF',
#   'ITGAM',
#   'TIMP1',
#   'ITGA4',
#   'ITGB2',
#   'ITGB1'],
#  127: ['ID2',
#   'MEOX2',
#   'WNT10A',
#   'WNT6',
#   'WNT8A',
#   'WNT8B',
#   'TCF7L1',
#   'WNT9B',
#   'WNT9A',
#   'WNT16',
#   'WNT5B',
#   'WNT11',
#   'TCF7',
#   'WNT7A',
#   'WNT10B',
#   'WNT2B',
#   'WNT3',
#   'WNT7B',
#   'WNT2',
#   'TCF7L2',
#   'WNT4',
#   'WNT5A',
#   'LEF1'],
#  130: ['ICT1'],
#  135: ['NHLRC2',
#   'SYN3',
#   'PAPLN',
#   'TTL',
#   'DCDC2B',
#   'DCDC2',
#   'ACRC',
#   'C9orf172',
#   'AKAP10',
#   'TRAIP',
#   'SYN1',
#   'RP1L1',
#   'TMEM65',
#   'LCMT1',
#   'ANGEL1',
#   'LMNB2',
#   'TELO2',
#   'PAN3',
#   'RBM17',
#   'MANBA',
#   'APTX',
#   'TBC1D20',
#   'NT5E',
#   'NARFL',
#   'TNRC6C',
#   'SPSB4',
#   'NARF',
#   'MASTL',
#   'SMPD2',
#   'USP39',
#   'SPSB1',
#   'TDRD3',
#   'RFX6',
#   'ATF6B',
#   'FIS1',
#   'CLSTN2',
#   'RBM43',
#   'MCF2L2',
#   'CNOT3',
#   'CLSTN3',
#   'TP73',
#   'CLSTN1',
#   'HIST1H1T',
#   'RFX8',
#   'DBF4B',
#   'WDR76',
#   'HIST1H1D',
#   'ATF6',
#   'ZNF598',
#   'PNKP',
#   'TP63',
#   'HIST1H1E',
#   'H1F0',
#   'DCLRE1B',
#   'WRNIP1',
#   'WIPI1',
#   'TIMELESS',
#   'HP1BP3',
#   'DCLRE1A',
#   'H1FX',
#   'WIPI2',
#   'SEPT12',
#   'POMP',
#   'ANLN',
#   'SMEK1',
#   'PDE12',
#   'HIST1H1B',
#   'ZC3H13',
#   'HCFC2',
#   'NANOS2',
#   'RFC1',
#   'LMNA',
#   'ATP13A5',
#   'ATP13A4',
#   'DCLRE1C',
#   'SEPT3',
#   'NANOS3',
#   'NANOS1',
#   'HIST1H1A',
#   'DBF4',
#   'H1FOO',
#   'ATP13A3',
#   'CCRN4L',
#   'HELB',
#   'EFNA4',
#   'SEPT9',
#   'LMNB1',
#   'TMEM189-UBE2V1',
#   'ATAD5',
#   'RFX5',
#   'HIST1H1C',
#   'EFNA3',
#   'SMEK2',
#   'EFNA5',
#   'EFNA2',
#   'ARID3C',
#   'ANGEL2',
#   'THOC2',
#   'FANCD2',
#   'XPOT',
#   'OBFC1',
#   'LPP',
#   'RFX2',
#   'EFNB3',
#   'DGUOK',
#   'POLD2',
#   'DNAJC9',
#   'VPS41',
#   'TMEM189',
#   'RFX3',
#   'PITRM1',
#   'RRN3',
#   'INSIG2',
#   'EFNA1',
#   'KIAA1432',
#   'TK2',
#   'INSIG1',
#   'CTNNA3',
#   'CSNK2B',
#   'ARID5A',
#   'MCF2',
#   'XPA',
#   'CIAO1',
#   'REV1',
#   'ARID3B',
#   'PKP3',
#   'PKP1',
#   'EFNB1',
#   'ATP13A2',
#   'UNG',
#   'TIPIN',
#   'PCID2',
#   'DSCC1',
#   'BECN1',
#   'POLK',
#   'CTNNA2',
#   'RAD18',
#   'ESCO1',
#   'ARID3A',
#   'TOPBP1',
#   'EFNB2',
#   'RPA4',
#   'MCM10',
#   'DOT1L',
#   'RFX1',
#   'PKP2',
#   'CNPPD1',
#   'C9orf69',
#   'SEPT7L',
#   'KNTC1',
#   'GBF1',
#   'ZWILCH',
#   'PIF1',
#   'CCS',
#   'MAK',
#   'ARVCF',
#   'SAC3D1',
#   'HCFC1',
#   'TRIP6',
#   'PRIM1',
#   'POLA2',
#   'EPS15L1',
#   'WDHD1',
#   'RECQL5',
#   'ESCO2',
#   'PARP2',
#   'CTNND2',
#   'CSTF2T',
#   'MCM3AP',
#   'MOK',
#   'PKP4',
#   'MUS81',
#   'MDC1',
#   'RAB3IL1',
#   'ANKRD32',
#   'ICK',
#   'SEPT14',
#   'DCK',
#   'CCNE2',
#   'CHTF18',
#   'RAB3IP',
#   'CHAF1B',
#   'CAMK2G',
#   'POLH',
#   'CDC23',
#   'SEPT10',
#   'UBE2V2',
#   'CAMK2D',
#   'SEPT8',
#   'HECTD1',
#   'RAD1',
#   'AANAT',
#   'NUP153',
#   'CAMK2B',
#   'CAMKK1',
#   'POLE3',
#   'CAMK2A',
#   'HMGB4',
#   'HIP1',
#   'ARFGEF1',
#   'POLI',
#   'UBE2V1',
#   'SOD3',
#   'SEPT11',
#   'SEPT1',
#   'CAMKK2',
#   'SEPT6',
#   'HIP1R',
#   'CNOT8',
#   'CTNNA1',
#   'EIF4G3',
#   'CTNND1',
#   'RBM25',
#   'CNOT7',
#   'RECQL',
#   'CDC45',
#   'SPAG6',
#   'TOX2',
#   'ERCC4',
#   'SEPT4',
#   'CSTF2',
#   'CCND1',
#   'IQCA1',
#   'CCNE1',
#   'PEX1',
#   'TOX3',
#   'DNA2',
#   'PAPD7',
#   'ARFGEF2',
#   'SEPT5',
#   'HMG20A',
#   'HMGB3',
#   'TOP3B',
#   'REV3L',
#   'RPA2',
#   'BLM',
#   'MCMDC2',
#   'TOX',
#   'CDC25B',
#   'WRN',
#   'FIGN',
#   'CSE1L',
#   'ZRANB3',
#   'TOP3A',
#   'TOX4',
#   'KIF12',
#   'MCM9',
#   'KIF24',
#   'SHPRH',
#   'HMG20B',
#   'EPS15',
#   'KIF6',
#   'KPNA5',
#   'POTEB',
#   'NKPD1',
#   'SMARCAL1',
#   'KPNA7',
#   'RAD21L1',
#   'POTEG',
#   'FIGNL1',
#   'PARP1',
#   'KIF26B',
#   'ERCC5',
#   'KPNA6',
#   'ANKRD35',
#   'POTEM',
#   'CASKIN1',
#   'POTEC',
#   'STARD9',
#   'KIF9',
#   'KIF16B',
#   'KIF13A',
#   'CDC25C',
#   'PSMD12',
#   'ATAD1',
#   'SEPT7',
#   'ANKRD24',
#   'CDC7',
#   'KIF26A',
#   'MCM8',
#   'ABTB1',
#   'EXO1',
#   'SPAST',
#   'SLMAP',
#   'KANK3',
#   'FANCM',
#   'KIF13B',
#   'FPGT-TNNI3K'],
#  142: ['PDZD2', 'INADL', 'GINS1'],
#  147: ['MPND', 'BRCC3', 'PSMD14'],
#  149: ['EDEM2',
#   'EDEM3',
#   'MSRA',
#   'EDEM1',
#   'MPDU1',
#   'ALPPL2',
#   'SRXN1',
#   'ALPI',
#   'MBLAC2',
#   'GSTO2',
#   'HAGHL',
#   'ALPP',
#   'PNKD',
#   'GMDS',
#   'ALPL',
#   'ETHE1',
#   'GSTO1',
#   'MSRB3',
#   'MSRB1',
#   'LACTB2',
#   'HAGH',
#   'IYD',
#   'ERO1LB',
#   'MSRB2',
#   'MANBA',
#   'GUSB',
#   'ISCA1',
#   'ACP1',
#   'ERO1L',
#   'CIAPIN1',
#   'CSDC2',
#   'BOLA3',
#   'YBX2',
#   'ALAD',
#   'CALR3',
#   'BOLA1',
#   'CARHSP1',
#   'COX17',
#   'ISCA2',
#   'COQ5',
#   'NFU1',
#   'TXNL1',
#   'GCLC',
#   'LIN28B',
#   'GPX5',
#   'L2HGDH',
#   'GLRX5',
#   'TP53RK',
#   'RBKS',
#   'GLRX2',
#   'LTA4H',
#   'PPIC',
#   'GPX6',
#   'GPX8',
#   'GLRX',
#   'ECHDC2',
#   'AUH',
#   'CSDA',
#   'GPX2',
#   'SPCS2',
#   'GPX7',
#   'PRDX5',
#   'ASL',
#   'OSGEPL1',
#   'GPX3',
#   'GPX1',
#   'GLRX3',
#   'GPX4',
#   'LIN28A',
#   'VPS29',
#   'PPIB',
#   'FLAD1',
#   'UBL5',
#   'STOML2',
#   'ETFDH',
#   'TSTA3',
#   'SDR42E2',
#   'UXS1',
#   'PAPSS2',
#   'DNAJC4',
#   'ASS1',
#   'TK1',
#   'CPOX',
#   'ECI1',
#   'ADK',
#   'SDR42E1',
#   'NTHL1',
#   'ECHDC1',
#   'PAPSS1',
#   'PGM5',
#   'DNAJC5G',
#   'NSDHL',
#   'ECI2',
#   'DNAJC11',
#   'HSD3B7',
#   'G6PD',
#   'HSD3B2',
#   'GTPBP5',
#   'DNAJC5B',
#   'CCS',
#   'DBT',
#   'DNAJC7',
#   'HSD3B1',
#   'CDYL2',
#   'ATP6V0B',
#   'CDY1B',
#   'CDY2B',
#   'CDY2A',
#   'CDY1',
#   'DNAJC30',
#   'ACO1',
#   'GTPBP10',
#   'IREB2',
#   'HIBCH',
#   'CDYL',
#   'CALR',
#   'DNAJC24',
#   'VBP1',
#   'DNAJC16',
#   'DNAJC22',
#   'DNAJC3',
#   'OSGEP',
#   'DNAJC5',
#   'PDHX',
#   'DNAJB8',
#   'DNAJC18',
#   'PPIL6',
#   'DNAJB14',
#   'EIF4E2',
#   'RAD1',
#   'PGM2L1',
#   'CLPP',
#   'ATP6V0C',
#   'PGM1',
#   'DLAT',
#   'DNAJB7',
#   'DNAJC25',
#   'DNAJB12',
#   'DNAJB2',
#   'SOD3',
#   'ECHS1',
#   'IDH2',
#   'DLST',
#   'DNAJC25-GNG10',
#   'EHHADH',
#   'DNAJB9',
#   'DNAJB11',
#   'ATP5G3',
#   'PGM2',
#   'ATP5G1',
#   'FBXO18',
#   'ATP5G2',
#   'IQCA1',
#   'DNAJA3',
#   'PEX1',
#   'IDH1',
#   'GBE1',
#   'UBA3',
#   'HADHA',
#   'DNAJB13',
#   'TOP3B',
#   'LDHAL6B',
#   'DNAJB5',
#   'DNAJB6',
#   'TSFM',
#   'GLUD1',
#   'DNAJB4',
#   'LDHAL6A',
#   'TALDO1',
#   'FIGN',
#   'VARS2',
#   'TOP3A',
#   'MDH1B',
#   'LDHC',
#   'AMFR',
#   'ATP6V1B2',
#   'TKTL1',
#   'PPID',
#   'TKTL2',
#   'SRPR',
#   'PGM3',
#   'NKTR',
#   'FIGNL1',
#   'ATP6V1B1',
#   'YBX1',
#   'PPIH',
#   'PPIG',
#   'ATAD1',
#   'TXNRD2',
#   'SPAST'],
#  150: ['TNNI3',
#   'ATP2B1',
#   'CACNA1D',
#   'CACNA1C',
#   'CACNA1S',
#   'ARPC2',
#   'RASEF',
#   'KIF26B',
#   'STARD9',
#   'KIF16B',
#   'KIF13A',
#   'KIF13B'],
#  155: ['C16orf96',
#   'NFXL1',
#   'ERGIC2',
#   'ERGIC3',
#   'ERGIC1',
#   'ERLEC1',
#   'YOD1',
#   'SCPEP1',
#   'OS9',
#   'POMP',
#   'NPLOC4',
#   'NFX1',
#   'DERL3',
#   'DERL2',
#   'SAR1A',
#   'SAR1B',
#   'UBE2G2',
#   'FAF2',
#   'NXF5',
#   'NXF2B',
#   'NXF3',
#   'NXF2',
#   'CPVL',
#   'HMGCR',
#   'DERL1',
#   'RNFT2',
#   'UGCG',
#   'PSMB11',
#   'ATP6V0B',
#   'RNFT1',
#   'ARHGEF28',
#   'YARS2',
#   'CTSA',
#   'PSMB8',
#   'HAS3',
#   'B3GNTL1',
#   'HAS2',
#   'NXF1',
#   'ATP6V0C',
#   'ALG5',
#   'HAS1',
#   'RNF145',
#   'PSMA8',
#   'DDOST',
#   'PSMB3',
#   'RNF139',
#   'ATP5G3',
#   'PSMA6',
#   'NUP85',
#   'ATP5G1',
#   'PSMB5',
#   'ATP5G2',
#   'ATG7',
#   'IQCA1',
#   'PEX1',
#   'DPM1',
#   'NET1',
#   'ARHGEF3',
#   'CHFR',
#   'FIGN',
#   'RPE',
#   'PLAA',
#   'HECW1',
#   'AMFR',
#   'PSMB4',
#   'PSMB7',
#   'SYVN1',
#   'PSMB10',
#   'PGM3',
#   'FIGNL1',
#   'PSMA3',
#   'UBA6',
#   'ATAD1',
#   'PSMA7',
#   'SPAST'],
#  156: ['AGPAT9'],
#  159: ['IGSF10',
#   'ARHGAP36',
#   'ARHGAP6',
#   'LRIT3',
#   'ARHGAP11B',
#   'LRIT1',
#   'ARHGAP11A',
#   'NCF4',
#   'SH3PXD2B',
#   'SH3PXD2A'],
#  184: ['REXO1L11P',
#   'REXO1L10P',
#   'DUS1L',
#   'REXO1',
#   'CECR1',
#   'ADA',
#   'REXO1L1',
#   'C9orf114',
#   'ADAL',
#   'TRMT11',
#   'REXO4',
#   'ISG20L2',
#   'AATF',
#   'ISG20',
#   'AEN',
#   'MAK16'],
#  201: ['MTHFR',
#   'MT-ND4',
#   'MT-ND4L',
#   'MT-ND5',
#   'MT-ND2',
#   'MT-ND3',
#   'MVK',
#   'MT-ND1',
#   'MVD',
#   'COQ5',
#   'AIFM2',
#   'MEMO1',
#   'DHCR24',
#   'N6AMT1',
#   'AGPAT1',
#   'NDUFS7',
#   'MSMO1',
#   'HAO2',
#   'AGPAT2',
#   'NDUFS8',
#   'HAO1',
#   'ETFDH',
#   'TATDN3',
#   'TATDN2',
#   'UNG',
#   'NDUFS3',
#   'NDUFS1',
#   'NDUFS2',
#   'TATDN1',
#   'HMGCS2',
#   'NDUFV1',
#   'NDUFV2',
#   'GTPBP5',
#   'MTHFD2L',
#   'HMGCS1',
#   'GTPBP10',
#   'CARNS1',
#   'MTHFD2',
#   'ACAT2',
#   'LARS2',
#   'MARS2',
#   'ACAA1',
#   'XPNPEP2',
#   'DDOST',
#   'EARS2',
#   'PARS2',
#   'ACAA2',
#   'TCEANC',
#   'HADHB',
#   'TCEANC2',
#   'DPM1',
#   'XPNPEP1',
#   'PEPD',
#   'MRPL27',
#   'TOP3B',
#   'PRPSAP1',
#   'PRPSAP2',
#   'TOP3A',
#   'ACAT1',
#   'TKTL1',
#   'TKTL2',
#   'TCEA3',
#   'PGM3',
#   'IKBKG',
#   'ATAD1',
#   'MRPS11',
#   'RPS18'],
#  215: ['MSLN',
#   'MMGT1',
#   'HSBP1',
#   'MRPL53',
#   'APOO',
#   'GADD45GIP1',
#   'MRPL44',
#   'TRIAP1',
#   'MRPL51',
#   'PTCD3',
#   'ISCA1',
#   'SCO2',
#   'NDUFA11',
#   'TOMM7',
#   'TOMM20L',
#   'NDUFB5',
#   'MRPL40',
#   'NDUFB6',
#   'NDUFA2',
#   'MRPL38',
#   'TIMM23B',
#   'NDUFA10',
#   'MRPL54',
#   'TIMM8A',
#   'TOMM22',
#   'UQCRQ',
#   'NDUFS7',
#   'NDUFB9',
#   'TCEB2',
#   'NDUFB7',
#   'NDUFS6',
#   'TIMM23',
#   'DNAJC15',
#   'TIMM8B',
#   'NDUFS8',
#   'DNAJC19',
#   'UQCRH',
#   'TOMM20',
#   'HNRNPR',
#   'FXC1',
#   'MRPL32',
#   'MRPS18A',
#   'TIMM9',
#   'MRPL23',
#   'TIMM13',
#   'MRPS18C',
#   'NDUFB10',
#   'TIMM10',
#   'MRPL17',
#   'MRPL27',
#   'MRPS14',
#   'UQCRC2',
#   'UQCRFS1',
#   'MRPS16',
#   'SLC25A3'],
#  218: ['DHRSX',
#   'SQRDL',
#   'PC',
#   'AGXT',
#   'PEX5',
#   'ACSM5',
#   'ACSM3',
#   'AMT',
#   'AACS',
#   'ACSM1',
#   'AIFM1',
#   'IDH3B',
#   'IDH2',
#   'IDH3A',
#   'IDH1'],
#  223: ['CENPW',
#   'PSMC3IP',
#   'BORA',
#   'BRCA2',
#   'CENPK',
#   'CDCA5',
#   'FANCD2',
#   'DTL',
#   'KNTC1',
#   'ZWILCH',
#   'NCAPD2',
#   'CHAF1A',
#   'CDC45',
#   'PRC1',
#   'RPA2',
#   'TTK',
#   'RAD21L1'],
#  227: ['DHRS11',
#   'DHRS7',
#   'AGPS',
#   'LDHD',
#   'HSDL1',
#   'AGMAT',
#   'ARG2',
#   'DIP2C',
#   'AKR1CL1',
#   'DIP2B',
#   'HSD17B3',
#   'NANS',
#   'GCLM',
#   'ACSF2',
#   'GFOD2',
#   'ARG1',
#   'D2HGDH',
#   'ACSF3',
#   'DIP2A',
#   'GFOD1',
#   'DHCR24',
#   'AKR1B15',
#   'HSD17B12',
#   'AKR1C4',
#   'AKR1C2',
#   'AKR1E2',
#   'AKR1C1',
#   'HOGA1',
#   'AKR1C3',
#   'NPL',
#   'GMPPA',
#   'AKR1D1',
#   'AKR1B10',
#   'AKR1A1',
#   'SORD',
#   'TSTA3',
#   'SDR42E2',
#   'UXS1',
#   'EIF2B3',
#   'IFFO2',
#   'AKR1B1',
#   'SDR42E1',
#   'NSDHL',
#   'HSD3B7',
#   'ALDH5A1',
#   'GMPPB',
#   'HSD3B2',
#   'HSD3B1',
#   'SPTLC1',
#   'ALDH4A1',
#   'ALDH16A1',
#   'EIF2B5',
#   'DMGDH',
#   'ALDH1L2',
#   'ALDH1L1',
#   'ALDH7A1',
#   'ALDH8A1',
#   'ALDH3B2',
#   'ALDH3A1',
#   'ALDH1A2',
#   'ALDH9A1',
#   'ALDH3A2',
#   'ALDH2',
#   'ALDH1A3',
#   'ALDH1B1',
#   'ALDH1A1'],
#  230: ['MAP3K4',
#   'TOPBP1',
#   'TAF6L',
#   'CCS',
#   'ANKRD32',
#   'TAF6',
#   'ERCC6L2',
#   'SOD3',
#   'SETX',
#   'BTAF1',
#   'CHD5',
#   'ERCC6'],
#  231: ['SH3YL1',
#   'TCERG1',
#   'ARL15',
#   'ARPC5L',
#   'ARPC3',
#   'ARPC5',
#   'CYB5B',
#   'HIP1',
#   'ARF6',
#   'HIP1R',
#   'PTK2',
#   'NCF4',
#   'SH3PXD2B',
#   'SH3PXD2A',
#   'WASL',
#   'HECTD2',
#   'SIRT6',
#   'PFN1',
#   'MYO16',
#   'PI4KB'],
#  232: ['PIK3R2', 'CBL'],
#  233: ['DPAGT1',
#   'GPX2',
#   'GPX7',
#   'GMPPA',
#   'GOT1L1',
#   'ACSM4',
#   'C10orf129',
#   'AKR1B10',
#   'ACSM2B',
#   'ACSM2A',
#   'ACSM5',
#   'ECHDC1',
#   'ACSM3',
#   'PGM5',
#   'ACSS3',
#   'UGCG',
#   'CNPPD1',
#   'GMPPB',
#   'COX4I1',
#   'AACS',
#   'GOT1',
#   'ACSS1',
#   'ACSM1',
#   'TREH',
#   'ACSS2',
#   'GOT2',
#   'PYGB',
#   'ATP7A',
#   'HAS3',
#   'ATP7B',
#   'PYGL',
#   'HAS2',
#   'PGM1',
#   'PYGM',
#   'HAS1',
#   'ECHS1',
#   'IDH2',
#   'EHHADH',
#   'IDH1',
#   'HADHA',
#   'ABCC6',
#   'TALDO1',
#   'MDH1B',
#   'TKTL1',
#   'TKTL2',
#   'ABCC1'],
#  238: ['DUSP11',
#   'RNGTT',
#   'EIF2B4',
#   'PSD2',
#   'RTEL1-TNFRSF6B',
#   'RTEL1',
#   'BAP1',
#   'TNPO2',
#   'EIF2B5',
#   'DHX57',
#   'ABCF3',
#   'TNPO1',
#   'DHX29',
#   'ABCF2',
#   'DHX30',
#   'CIRH1A',
#   'EIF3G',
#   'ERCC2',
#   'DHX36'],
#  239: ['TRAIP',
#   'IBTK',
#   'PGAM5',
#   'GPS1',
#   'UBE2F',
#   'SPRYD3',
#   'FBXL20',
#   'ATG3',
#   'FBXL2',
#   'PLA2G15',
#   'UBE2M',
#   'WDR64',
#   'SPOPL',
#   'TIMM23B',
#   'CASP7',
#   'TOMM70A',
#   'SNX30',
#   'SNX8',
#   'SNX7',
#   'VHL',
#   'TIMM23',
#   'UBE2G2',
#   'SLC30A1',
#   'SEC14L6',
#   'UBL5',
#   'RANBP10',
#   'CLVS2',
#   'SLC30A10',
#   'SEC14L3',
#   'SNX4',
#   'SEC14L4',
#   'CLVS1',
#   'CHMP3',
#   'SPOP',
#   'RANBP9',
#   'SNX2',
#   'SNX1',
#   'TTPA',
#   'SEC14L2',
#   'TTPAL',
#   'STAMBPL1',
#   'PDIK1L',
#   'RLBP1',
#   'SEC14L5',
#   'RNF103-CHMP3',
#   'MPND',
#   'STAMBP',
#   'TCEB1',
#   'SEC14L1',
#   'NEDD8-MDP1',
#   'UBE2C',
#   'ADRM1',
#   'NAE1',
#   'PSMD8',
#   'ANAPC5',
#   'PSMA8',
#   'DDB2',
#   'BRCC3',
#   'FBXW11',
#   'PFDN2',
#   'FBXO18',
#   'ANAPC11',
#   'PSMA2',
#   'UBA3',
#   'RAB40C',
#   'COPS6',
#   'HECTD2',
#   'CHFR',
#   'MCM9',
#   'PLAA',
#   'PSMB4',
#   'DARS',
#   'PSMD14',
#   'IKBKG',
#   'UBE2J1',
#   'DNAJC2',
#   'RNF40',
#   'PSMD12',
#   'PSMA7',
#   'DDB1',
#   'PSMD7'],
#  241: ['AMDHD2',
#   'CD320',
#   'DPCR1',
#   'GMCL1',
#   'NOMO3',
#   'TGDS',
#   'NOMO2',
#   'NOMO1',
#   'XPO7',
#   'GMDS',
#   'MAT2B',
#   'SCO1',
#   'GLS',
#   'UAP1L1',
#   'MPI',
#   'UAP1',
#   'UPP2',
#   'SCO2',
#   'TTC1',
#   'AGMAT',
#   'ARG2',
#   'NAT8',
#   'CARKD',
#   'NAA30',
#   'UPP1',
#   'YJEFN3',
#   'ARG1',
#   'SORL1',
#   'EDC3',
#   'APOA1BP',
#   'PIGV',
#   'GDE1',
#   'GRINA',
#   'FAIM2',
#   'TMBIM1',
#   'MALSU1',
#   'UGDH',
#   'PC',
#   'CLPX',
#   'PPAT',
#   'OSGEPL1',
#   'TMBIM4',
#   'ME3',
#   'NAA20',
#   'ME2',
#   'VPS4A',
#   'GMPPA',
#   'HACL1',
#   'VPS4B',
#   'NAA10',
#   'NAA11',
#   'UGP2',
#   'PMM1',
#   'PMM2',
#   'MARCH3',
#   'TSTA3',
#   'SDR42E2',
#   'ME1',
#   'UXS1',
#   'MT-ATP6',
#   'EIF2B3',
#   'POT1',
#   'SCLY',
#   'MARCH2',
#   'SDR42E1',
#   'LGSN',
#   'NFS1',
#   'GDI1',
#   'POLK',
#   'NSDHL',
#   'MSH4',
#   'UGCG',
#   'HSD3B7',
#   'CDS2',
#   'GMPPB',
#   'SPTLC3',
#   'HSD3B2',
#   'REN',
#   'AZIN1',
#   'HSD3B1',
#   'ADC',
#   'MTO1',
#   'MRPL32',
#   'NASP',
#   'ATP6V0B',
#   'SPTLC2',
#   'SPRTN',
#   'CDS1',
#   'GALE',
#   'NAA50',
#   'EIF2B5',
#   'OSGEP',
#   'HAS3',
#   'ADSL',
#   'POLH',
#   'HAS2',
#   'ODC1',
#   'SEC23A',
#   'PGM2L1',
#   'ATP6V0C',
#   'HAS1',
#   'ARFGEF1',
#   'ABCF1',
#   'POLI',
#   'GLUL',
#   'PARS2',
#   'GNPNAT1',
#   'ATP5G3',
#   'PGM2',
#   'GARS',
#   'ATP5G1',
#   'ABCF3',
#   'DCP2',
#   'ATP5G2',
#   'GDI2',
#   'ARFGEF2',
#   'ABCF2',
#   'THNSL1',
#   'ATP5D',
#   'PPCDC',
#   'ITPA',
#   'PRPSAP2',
#   'TENC1',
#   'DDX60',
#   'SF3A2',
#   'NDUFAB1',
#   'MLH1',
#   'TTC27',
#   'SRPR',
#   'PGM3',
#   'KPNA6',
#   'UBA6',
#   'CDC7'],
#  242: ['PLCH2',
#   'PLCL2',
#   'PLCH1',
#   'PLCZ1',
#   'PLCL1',
#   'PLCD4',
#   'PLCD3',
#   'PLCD1',
#   'PLCE1',
#   'SRRM1',
#   'PLCB4',
#   'PLCB2',
#   'PLCB3',
#   'PLCB1'],
#  243: ['USP35',
#   'IFT88',
#   'USP38',
#   'USP12',
#   'CBWD7',
#   'MKRN2',
#   'CBWD6',
#   'CBWD3',
#   'CPSF4L',
#   'NOL9',
#   'CBWD2',
#   'ZC3H6',
#   'WIBG',
#   'CBWD5',
#   'ZC3H8',
#   'CBWD1',
#   'ZC3H3',
#   'USP46',
#   'FIP1L1',
#   'USP1',
#   'RBBP6',
#   'CPSF1',
#   'CPSF4',
#   'SYMPK',
#   'RTN2',
#   'SSU72',
#   'RTN3',
#   'INTS9',
#   'ARPC4',
#   'DCLRE1B',
#   'ANAPC7',
#   'DCLRE1A',
#   'DCLRE1C',
#   'RTN1',
#   'ARPC5L',
#   'ARPC3',
#   'CLP1',
#   'ORC3',
#   'CPSF3L',
#   'ANAPC4',
#   'ARPC5',
#   'CTU2',
#   'RTN4',
#   'PAPOLB',
#   'PAPOLG',
#   'ANAPC2',
#   'ANAPC1',
#   'LAS1L',
#   'TEX10',
#   'CSTF2T',
#   'RBBP5',
#   'MDN1',
#   'ARPC2',
#   'CDC23',
#   'ZNF593',
#   'TRMT2B',
#   'TRMT2A',
#   'FAM203B',
#   'FAM203A',
#   'ANAPC5',
#   'PAPOLA',
#   'CPSF3',
#   'WDR82',
#   'TRMT11',
#   'VPS72',
#   'ANAPC10',
#   'ZNHIT1',
#   'CSTF2',
#   'CPSF2',
#   'RIOK2',
#   'WASL',
#   'CIRH1A',
#   'NOC4L',
#   'METAP1D',
#   'ACTR6',
#   'CDC16',
#   'METAP1',
#   'PAK1IP1',
#   'RBM19'],
#  245: ['SLC26A3',
#   'SLC1A5',
#   'IMPAD1',
#   'MIPEP',
#   'HGD',
#   'NAGS',
#   'PSPH',
#   'NLN',
#   'THOP1',
#   'DERA',
#   'CYP1B1',
#   'SURF4',
#   'PRODH',
#   'PSAT1',
#   'AQP6',
#   'CYP2C19',
#   'ISCU',
#   'AQP8',
#   'GOPC',
#   'THNSL2',
#   'TTR',
#   'MIP',
#   'CYP2C9',
#   'CYP2B6',
#   'AQP5',
#   'NPL',
#   'AQP4',
#   'AQP2',
#   'CYP1A2',
#   'CYP1A1',
#   'PHGDH',
#   'AGXT',
#   'FLAD1',
#   'AQP1',
#   'UGP2',
#   'CYP2E1',
#   'TRMU',
#   'SEC24C',
#   'PAPSS2',
#   'IFFO2',
#   'TARBP1',
#   'SCLY',
#   'NFS1',
#   'PAPSS1',
#   'GLDC',
#   'PGAM4',
#   'CMSS1',
#   'ALDH5A1',
#   'SPTLC3',
#   'ADC',
#   'SPTLC2',
#   'SPTLC1',
#   'DBNL',
#   'AQP3',
#   'ALDH4A1',
#   'IREB2',
#   'HTRA3',
#   'CARNS1',
#   'HTRA4',
#   'TYSND1',
#   'BPGM',
#   'GPN1',
#   'ALDH16A1',
#   'HTT',
#   'DMGDH',
#   'POR',
#   'HTRA1',
#   'ALDH1L2',
#   'AHCYL2',
#   'ODC1',
#   'ALDH1L1',
#   'ALDH7A1',
#   'ALDH8A1',
#   'ALDH3B2',
#   'PPCS',
#   'HTRA2',
#   'ALDH3A1',
#   'EHHADH',
#   'ALDH1A2',
#   'PTGES3L-AARSD1',
#   'ALDH9A1',
#   'ALDH3A2',
#   'ALDH2',
#   'ALDH1A3',
#   'ALDH1B1',
#   'ALDH1A1',
#   'THNSL1',
#   'PGAM2',
#   'PPCDC',
#   'PGAM1',
#   'AHCYL1',
#   'NOS1',
#   'PSMD14',
#   'PSMD9',
#   'AHCY',
#   'FARSA',
#   'HBS1L',
#   'UBA6',
#   'TXNRD2',
#   'PSMD7',
#   'NOS3',
#   'NOS2'],
#  249: ['EXOSC9',
#   'PRPSAP1',
#   'PRPSAP2',
#   'DDX3Y',
#   'DDX4',
#   'POTEB',
#   'NKPD1',
#   'POTEG',
#   'ANKRD35',
#   'PSMD9',
#   'POTEM',
#   'CASKIN1',
#   'POTEC',
#   'ANKRD24',
#   'ABTB1',
#   'KANK3',
#   'FPGT-TNNI3K'],
#  252: ['PRKRA',
#   'SNAP91',
#   'SAMD4B',
#   'SAMD4A',
#   'DCP1B',
#   'TIA1',
#   'TIAL1',
#   'ATXN2L',
#   'QKI',
#   'SF1',
#   'ATXN2',
#   'RAD18',
#   'EIF4E3',
#   'KHDRBS1',
#   'BCL2L2',
#   'MCM3AP',
#   'EIF4E2',
#   'ZCCHC13',
#   'BCL2L2-PABPN1',
#   'PABPN1',
#   'EIF4G3',
#   'ZCCHC9',
#   'DCP2',
#   'EIF4E1B',
#   'POLDIP3',
#   'MRPL27',
#   'SNRNP35',
#   'PABPC4L',
#   'PCBP1',
#   'PABPC5',
#   'DDX3Y',
#   'DDX4',
#   'DAZ3',
#   'MYO16',
#   'ZCCHC14',
#   'DAZ2',
#   'RBM3',
#   'DAZ4'],
#  253: ['ZNF598',
#   'USP50',
#   'USP29',
#   'USP26',
#   'USP37',
#   'RPAP2',
#   'TMEM189-UBE2V1',
#   'TMEM189',
#   'USP43',
#   'UFD1L',
#   'IPO9',
#   'RNFT2',
#   'USP21',
#   'USP8',
#   'STAMBPL1',
#   'USP2',
#   'PHF20L1',
#   'RNFT1',
#   'MPND',
#   'GTF2F2',
#   'GTF2F1',
#   'UBE2V2',
#   'HECTD3',
#   'KIAA0317',
#   'STUB1',
#   'UBE2V1',
#   'BRCC3',
#   'POLR2D',
#   'ANAPC11',
#   'RNF7',
#   'COPS6',
#   'HECTD2',
#   'PSMD14',
#   'UBE2J1',
#   'PSMD7'],
#  254: ['WIPF2',
#   'WIPF1',
#   'HIP1',
#   'HIP1R',
#   'CDC37',
#   'CIB3',
#   'CIB2',
#   'GUCA1B',
#   'GUCA1C',
#   'EFCAB1',
#   'KCNIP1',
#   'NCS1',
#   'GUCA1A',
#   'KCNIP2',
#   'HPCAL4',
#   'MYO16',
#   'KCNIP4',
#   'KCNIP3',
#   'VSNL1',
#   'RCVRN',
#   'KIF26A',
#   'MYL6B'],
#  260: ['LHX3',
#   'LHX4',
#   'GCM2',
#   'SSBP4',
#   'GCM1',
#   'SSBP2',
#   'SSBP3',
#   'RFNG',
#   'LDB2',
#   'LFNG',
#   'MFNG',
#   'LDB1',
#   'WRB',
#   'TBX4',
#   'TBR1',
#   'TBX6',
#   'TBX19',
#   'T',
#   'EYS',
#   'TBX2',
#   'EOMES',
#   'MGA',
#   'TBX5',
#   'TBX21',
#   'TBX3',
#   'ASNA1',
#   'POTEB',
#   'NKPD1',
#   'POTEG',
#   'ANKRD35',
#   'POTEM',
#   'CASKIN1',
#   'POTEC',
#   'ANKRD24',
#   'ABTB1',
#   'KANK3',
#   'FPGT-TNNI3K'],
#  262: ['PLEKHG3',
#   'PLEKHG1',
#   'FERMT3',
#   'PLEKHG2',
#   'FBLIM1',
#   'WTIP',
#   'LIMD1',
#   'ARHGEF6',
#   'KY',
#   'ARHGEF7',
#   'MICAL2',
#   'MICAL3',
#   'NLK',
#   'NF2',
#   'SMTN',
#   'ARHGAP31',
#   'AJUBA',
#   'FZD5',
#   'LPP',
#   'EFNB3',
#   'ZYX',
#   'NCK2',
#   'CTNNA3',
#   'EFNB1',
#   'PLS3',
#   'PCBP3',
#   'CTNNA2',
#   'PLS1',
#   'EXOC4',
#   'PCBP4',
#   'EFNB2',
#   'UGCG',
#   'EHBP1L1',
#   'C9orf69',
#   'SEPT7L',
#   'TNNT1',
#   'DNAH12',
#   'VAV1',
#   'SPATA13',
#   'TRIP6',
#   'FLNA',
#   'SPTB',
#   'SPTBN5',
#   'DNAH2',
#   'EZR',
#   'DNAH10',
#   'PARP2',
#   'FLNB',
#   'DNAH3',
#   'LCP1',
#   'NGEF',
#   'DNAH1',
#   'DNAH7',
#   'DNAH6',
#   'DNAH5',
#   'ARHGEF16',
#   'CDT1',
#   'SPTBN4',
#   'SEPT14',
#   'DNAH17',
#   'ARHGEF11',
#   'HAS3',
#   'FLNC',
#   'DNAH9',
#   'DNAH11',
#   'SHH',
#   'SEPT10',
#   'DYNC2H1',
#   'HAS2',
#   'SEPT8',
#   'UTRN',
#   'SPTBN2',
#   'AKAP13',
#   'HAS1',
#   'ARHGEF12',
#   'SOD3',
#   'PFN4',
#   'IQGAP2',
#   'SEPT11',
#   'STX11',
#   'SEPT1',
#   'SEPT6',
#   'CTNNA1',
#   'IQGAP3',
#   'PPP2R5C',
#   'SPTA1',
#   'SEPT4',
#   'NCF4',
#   'SH3PXD2B',
#   'DMD',
#   'PCBP2',
#   'SPTBN1',
#   'PFN2',
#   'NET1',
#   'ARHGEF3',
#   'TRAF6',
#   'SH3PXD2A',
#   'SEPT5',
#   'NCK1',
#   'PCBP1',
#   'RAB8B',
#   'CORO2A',
#   'PFN1',
#   'PIP5KL1',
#   'MAPRE2',
#   'SPTAN1',
#   'SEPT7',
#   'MAPRE3',
#   'IQGAP1',
#   'ACTN4',
#   'MYL6B',
#   'PIP4K2C'],
#  263: ['CWH43',
#   'POMT2',
#   'POMT1',
#   'SH2D1B',
#   'INPP5E',
#   'INPP5J',
#   'INPP5K',
#   'ARHGEF26',
#   'SCFD1',
#   'FIG4',
#   'INPP5B',
#   'INPPL1',
#   'OCRL',
#   'INPP5D',
#   'ARHGEF1',
#   'ARHGEF12',
#   'PFN4',
#   'PGS1',
#   'PFN2',
#   'NET1',
#   'ARHGEF3',
#   'SACM1L',
#   'PFN1'],
#  285: ['DHRS11',
#   'CRYL1',
#   'AGMAT',
#   'ARG2',
#   'ALDH6A1',
#   'GFOD2',
#   'ARG1',
#   'L2HGDH',
#   'MCEE',
#   'GFOD1',
#   'SARDH',
#   'HADH',
#   'ACSM4',
#   'C10orf129',
#   'ACSM2B',
#   'ETFDH',
#   'ACSM2A',
#   'IFFO2',
#   'ACSM5',
#   'ECI1',
#   'ECHDC1',
#   'ACSM3',
#   'GLDC',
#   'NDUFS1',
#   'ACSS3',
#   'ECI2',
#   'ALDH5A1',
#   'HSD17B4',
#   'CDYL2',
#   'AACS',
#   'CDY1B',
#   'CDY2B',
#   'CDY2A',
#   'CDY1',
#   'ALDH4A1',
#   'ACSS1',
#   'ACSM1',
#   'HIBCH',
#   'CDYL',
#   'ETFA',
#   'ACSS2',
#   'ALDH16A1',
#   'DMGDH',
#   'ALDH1L2',
#   'ALDH1L1',
#   'ALDH7A1',
#   'ALDH8A1',
#   'ALDH3B2',
#   'ACAT2',
#   'ACAA1',
#   'ECHS1',
#   'ALDH3A1',
#   'EHHADH',
#   'ACAA2',
#   'ALDH1A2',
#   'ALDH9A1',
#   'ALDH3A2',
#   'ALDH2',
#   'ALDH1A3',
#   'HADHB',
#   'ALDH1B1',
#   'ALDH1A1',
#   'HADHA',
#   'ACAT1',
#   'SUCLA2',
#   'SUCLG2'],
#  290: ['VAV2', 'VAV1'],
#  296: ['KIN', 'ORC3', 'MNAT1', 'DCK', 'TKTL1', 'TKTL2', 'STAT3', 'CMPK2'],
#  300: ['PQBP1',
#   'PRPF18',
#   'DDX46',
#   'CSTF1',
#   'SNIP1',
#   'GTF2F2',
#   'PSME3',
#   'TRMT112',
#   'CCNK',
#   'ILF2',
#   'GTF2F1',
#   'FCF1',
#   'POLR2D',
#   'ISG20L2',
#   'RRP8',
#   'SNRNP35',
#   'FTSJ1',
#   'EXOSC2',
#   'PRPF4',
#   'RPLP1',
#   'AEN',
#   'BUD31',
#   'KRI1',
#   'DAZ3',
#   'DAZ2',
#   'RBM3',
#   'UTP6',
#   'DAZ4'],
#  319: ['DLK2'],
#  321: ['SERPINB12',
#   'TMPRSS11D',
#   'SERPINB10',
#   'SERPINI2',
#   'SERPINB13',
#   'SERPINI1',
#   'SERPINB8',
#   'SERPINB3',
#   'SERPINA10',
#   'SERPINB7',
#   'SERPINB4',
#   'SERPINB9',
#   'SERPINB6',
#   'SERPINB1',
#   'SERPINB5',
#   'SERPINF1',
#   'SERPIND1',
#   'SERPINB2',
#   'SERPINE2',
#   'SERPING1',
#   'CTSG',
#   'GRN',
#   'PLAU',
#   'SERPINF2',
#   'SERPINH1',
#   'SERPINC1',
#   'SERPINE1',
#   'PLG'],
#  346: ['PDGFD',
#   'PDGFC',
#   'ANGPT4',
#   'PGF',
#   'POU5F1B',
#   'LCTL',
#   'CSF1',
#   'SEMA3C',
#   'KLB',
#   'SEMA3F',
#   'PDGFA',
#   'SEMA3E',
#   'FGF14',
#   'GRB7',
#   'IGFBP7',
#   'FGF21',
#   'FGF11',
#   'SEMA6A',
#   'PROX1',
#   'NDST2',
#   'FGF17',
#   'ANGPT2',
#   'FGF18',
#   'VEGFB',
#   'SEMA3A',
#   'NDST1',
#   'FGF8',
#   'FGF5',
#   'FGF6',
#   'FGF23',
#   'FGF22',
#   'FGF12',
#   'VEGFC',
#   'KITLG',
#   'FIGF',
#   'KL',
#   'FGF19',
#   'FGF10',
#   'NTN1',
#   'ANGPT1',
#   'FGF4',
#   'FGF20',
#   'SHC4',
#   'FGF9',
#   'LCT',
#   'FGF7',
#   'PNISR',
#   'FGF13',
#   'PDGFB',
#   'FGF1',
#   'SHC3',
#   'SHC2',
#   'ACP5',
#   'KCNMA1',
#   'CNTN2',
#   'VWA5B1',
#   'VWA5B2',
#   'ITIH6',
#   'ITIH5',
#   'HGF',
#   'PIK3AP1',
#   'VWA5A',
#   'EDA',
#   'CHL1',
#   'POU5F1',
#   'THUMPD1',
#   'KIAA1109',
#   'IGF1',
#   'GDF6',
#   'BMP8B',
#   'ABCG8',
#   'ITIH3',
#   'ERLEC1',
#   'ROBO1',
#   'BMP10',
#   'INS',
#   'ITIH2',
#   'ABCG4',
#   'ITIH1',
#   'KRT79',
#   'NGF',
#   'FGF2',
#   'ABCG1',
#   'AMH',
#   'APLP2',
#   'VEGFA',
#   'TXNIP',
#   'ACVRL1',
#   'ABCG5',
#   'MIXL1',
#   'SFRP4',
#   'ARHGAP35',
#   'CD40',
#   'BMP5',
#   'TPK1',
#   'ITIH4',
#   'BMP6',
#   'ITGA5',
#   'HHATL',
#   'EGF',
#   'BMPR1B',
#   'UGDH',
#   'PTPN4',
#   'HHAT',
#   'FZD10',
#   'TSC2',
#   'FZD8',
#   'FZD7',
#   'FZD6',
#   'SFRP2',
#   'FRZB',
#   'EFNA4',
#   'BMPR1A',
#   'EFNA3',
#   'BMP7',
#   'STAT4',
#   'EFNA5',
#   'EFNA2',
#   'PAX7',
#   'NUBPL',
#   'NUBP1',
#   'SFRP1',
#   'FZD1',
#   'SOCS3',
#   'FZD5',
#   'GRAPL',
#   'FZD2',
#   'FZD4',
#   'EFNB3',
#   'TGFB3',
#   'SPRY2',
#   'TGFB2',
#   'PTPRO',
#   'EFNA1',
#   'ACVR1',
#   'APC2',
#   'SELRC1',
#   'PTPRB',
#   'PAX3',
#   'NCAM1',
#   'NUBP2',
#   'GRAP',
#   'PTPRN2',
#   'BMP2',
#   'VASP',
#   'EFNB1',
#   'PDF',
#   'PTPRK',
#   'PDK3',
#   'BMP4',
#   'PTK2B',
#   'EFNB2',
#   'PDK4',
#   'PDK2',
#   'PTPRJ',
#   'GRAP2',
#   'BCKDK',
#   'PTPN13',
#   'RASA1',
#   'STAT2',
#   'STAT6',
#   'PDK1',
#   'MTFMT',
#   'PAX6',
#   'IRS1',
#   'SRPK3',
#   'STAT5B',
#   'PTPRZ1',
#   'SEL1L3',
#   'LRP2BP',
#   'B3GNTL1',
#   'ALG1L',
#   'PLD6',
#   'SEL1L2',
#   'FN1',
#   'CRKL',
#   'WNT8A',
#   'PPCS',
#   'CAMKK1',
#   'STAT5A',
#   'ALG5',
#   'ALG11',
#   'ALG1',
#   'PDLIM5',
#   'CRY2',
#   'TAP2',
#   'CRY1',
#   'ABCB10',
#   'SHC1',
#   'TGFBR1',
#   'PTPN2',
#   'ABCB9',
#   'ALG2',
#   'ABCB8',
#   'CAMKK2',
#   'SEL1L',
#   'PLCB4',
#   'TAP1',
#   'PTK2',
#   'PLCB2',
#   'MPP1',
#   'CBL',
#   'SAT1',
#   'MPP4',
#   'KIAA0141',
#   'REL',
#   'PPP2R5B',
#   'PDPK1',
#   'TGFB1',
#   'PGS1',
#   'MPP7',
#   'PPP2R5E',
#   'PLCB3',
#   'PIGA',
#   'PTPN12',
#   'PLCB1',
#   'PPP2R5C',
#   'WNT5B',
#   'WNT11',
#   'WNT7A',
#   'ITGB1',
#   'ABCC10',
#   'DPM1',
#   'PPP2R5A',
#   'WNT10B',
#   'MPP5',
#   'MPP2',
#   'APC',
#   'ABCC9',
#   'WNT2B',
#   'NCK1',
#   'WNT3',
#   'MPP6',
#   'PTPRG',
#   'PPCDC',
#   'PTPN6',
#   'MPP3',
#   'SNRNP35',
#   'ITPA',
#   'ABCC12',
#   'PPP2R5D',
#   'CDC25B',
#   'ABCC11',
#   'ABCC6',
#   'ABCC3',
#   'WNT7B',
#   'RPE',
#   'ABCC4',
#   'WNT2',
#   'ABCB5',
#   'ABCC5',
#   'CBS',
#   'ABCC8',
#   'RPTOR',
#   'WNT4',
#   'DDX4',
#   'IKBKG',
#   'ABCC1',
#   'ABCB4',
#   'STAT1',
#   'ABCC2',
#   'ABCB11',
#   'WNT5A',
#   'CDC25C',
#   'MAPK9',
#   'LEF1',
#   'SLMAP',
#   'ABCB1',
#   'STAT3'],
#  353: ['AFAP1',
#   'CYLD',
#   'CISH',
#   'LCT',
#   'SOCS4',
#   'OXSR1',
#   'KCNMA1',
#   'VWA5B1',
#   'STK39',
#   'VWA5B2',
#   'ITIH6',
#   'ITIH5',
#   'SOCS2',
#   'VWA5A',
#   'ITIH3',
#   'ITIH2',
#   'ITIH1',
#   'KRT79',
#   'DAB2',
#   'MAP2K4',
#   'MGAM',
#   'CD40',
#   'CLK4',
#   'MAP2K6',
#   'MAP2K3',
#   'TPK1',
#   'ITIH4',
#   'SOCS1',
#   'STK35',
#   'HHATL',
#   'HHAT',
#   'ABI3',
#   'FRZB',
#   'EFNA4',
#   'CLK1',
#   'EFNA3',
#   'CLK3',
#   'CLK2',
#   'STAT4',
#   'EFNA5',
#   'EFNA2',
#   'TBC1D14',
#   'NUBPL',
#   'NUBP1',
#   'CEBPA',
#   'SOCS3',
#   'IRS2',
#   'GRAPL',
#   'EFNB3',
#   'SPRY2',
#   'ULK1',
#   'PTPRO',
#   'EFNA1',
#   'APC2',
#   'SELRC1',
#   'NCK2',
#   'KSR1',
#   'NUBP2',
#   'GRAP',
#   'VASP',
#   'EFNB1',
#   'USP6NL',
#   'ULK3',
#   'PDF',
#   'PTPRK',
#   'PDK3',
#   'EFNB2',
#   'PDK4',
#   'PDK2',
#   'PDIK1L',
#   'GRAP2',
#   'BCKDK',
#   'STAT2',
#   'STAT6',
#   'PDLIM4',
#   'PDK1',
#   'MTFMT',
#   'EPS15L1',
#   'MAP2K7',
#   'IRS1',
#   'SRPK3',
#   'STAT5B',
#   'SEL1L3',
#   'MYD88',
#   'PTPRR',
#   'LRP2BP',
#   'B3GNTL1',
#   'TBC1D30',
#   'ALG1L',
#   'PLD6',
#   'ARAF',
#   'SEL1L2',
#   'PPCS',
#   'LPXN',
#   'GRTP1',
#   'CAMKK1',
#   'STAT5A',
#   'ALG5',
#   'ALG11',
#   'ALG1',
#   'TBC1D2',
#   'PDLIM5',
#   'CRY2',
#   'TAP2',
#   'CRY1',
#   'TBC1D2B',
#   'WNT9B',
#   'ABCB10',
#   'SHC1',
#   'WNT9A',
#   'TRIM23',
#   'ABCB9',
#   'ALG2',
#   'ABCB8',
#   'CAMKK2',
#   'SEL1L',
#   'WNT16',
#   'TAP1',
#   'PTK2',
#   'MPP1',
#   'MPP4',
#   'KIAA0141',
#   'REL',
#   'PPP2R5B',
#   'PDPK1',
#   'PGS1',
#   'MPP7',
#   'PPP2R5E',
#   'PIGA',
#   'PPP2R5C',
#   'WNT5B',
#   'WNT7A',
#   'ITGB1',
#   'ABCC10',
#   'DPM1',
#   'PTPRF',
#   'CDC37',
#   'SEC13',
#   'PPP2R5A',
#   'MPP5',
#   'MPP2',
#   'APC',
#   'ABCC9',
#   'WNT2B',
#   'NCK1',
#   'WNT3',
#   'MPP6',
#   'PPCDC',
#   'PTPN6',
#   'MPP3',
#   'ITPA',
#   'ABCC12',
#   'PPP2R5D',
#   'CDC25B',
#   'ABCC11',
#   'ABCC6',
#   'ABCC3',
#   'WNT7B',
#   'RPE',
#   'ABCC4',
#   'WNT2',
#   'ABCB5',
#   'ABCC5',
#   'EPS15',
#   'CBS',
#   'ABCC8',
#   'MAPK10',
#   'RPTOR',
#   'WNT4',
#   'CCNH',
#   'ABCC1',
#   'ABCB4',
#   'STAT1',
#   'ABCC2',
#   'ABCB11',
#   'WNT5A',
#   'CDC25C',
#   'MAPK9',
#   'LEF1',
#   'SLMAP',
#   'ABCB1',
#   'STAT3'],
#  357: ['BCL2L14',
#   'BOK',
#   'NMRK1',
#   'NMRK2',
#   'PPP1R11',
#   'CAB39L',
#   'ZMAT2',
#   'BAK1',
#   'BCL2A1',
#   'MCL1',
#   'SATL1',
#   'CAB39',
#   'GPCPD1',
#   'CWC25',
#   'HTATSF1',
#   'DLK2',
#   'SYF2',
#   'RQCD1',
#   'CCDC94',
#   'LSM4',
#   'PDZD2',
#   'RBM22',
#   'BCL2L1',
#   'UBXN2A',
#   'SF3B4',
#   'DLG5',
#   'CNOT2',
#   'MYD88',
#   'ISY1-RAB43',
#   'ISY1',
#   'UBXN2B',
#   'UBXN11',
#   'PRPF39',
#   'PTPRQ',
#   'AANAT',
#   'BCL2',
#   'TFIP11',
#   'MFAP1',
#   'GNPNAT1',
#   'CNOT8',
#   'INADL',
#   'RBM25',
#   'CNOT7',
#   'SAT1',
#   'NSFL1C',
#   'CAPZA3',
#   'CRNKL1',
#   'RASGEF1B',
#   'HELQ',
#   'GINS1',
#   'CCDC130',
#   'XAB2',
#   'CAPZA2',
#   'SART1',
#   'MIB2',
#   'SF3A2',
#   'LSM2',
#   'PRPF6',
#   'PAF1',
#   'BUD31',
#   'CAPZA1',
#   'POTEB',
#   'NKPD1',
#   'POTEG',
#   'CNOT1',
#   'LSM10',
#   'ANKRD35',
#   'SF3A1',
#   'POTEM',
#   'CASKIN1',
#   'POTEC',
#   'SNRPB2',
#   'ANKRD24',
#   'ABTB1',
#   'LSM6',
#   'KANK3',
#   'FPGT-TNNI3K'],
#  360: ['HHEX', 'MEIS2', 'ANPEP', 'SHH', 'RBPJ'],
#  361: ['CCDC85A', 'SLC23A2', 'SLC9A8', 'ICK'],
#  362: ['DTX4',
#   'DTX2',
#   'DTX1',
#   'PARVG',
#   'PARVB',
#   'PDZRN3',
#   'PARP3',
#   'PARVA',
#   'PDZRN4',
#   'PARP4',
#   'NEURL',
#   'NEURL1B',
#   'TATDN3',
#   'TATDN2',
#   'GSC2',
#   'ISX',
#   'RHOXF1',
#   'ESX1',
#   'SEBOX',
#   'RHOXF2B',
#   'DRGX',
#   'DPRX',
#   'PSEN2',
#   'PAAF1',
#   'NOBOX',
#   'ALX1',
#   'ALX3',
#   'TATDN1',
#   'RAX2',
#   'SHOX',
#   'PRRX2',
#   'DMBX1',
#   'SHOX2',
#   'OTP',
#   'PROP1',
#   'RAX',
#   'PRRX1',
#   'MAK',
#   'LHX6',
#   'RHOXF2',
#   'UNCX',
#   'ISL2',
#   'HESX1',
#   'ARX',
#   'LHX8',
#   'HOPX',
#   'NDOR1',
#   'LMX1B',
#   'HTRA3',
#   'HTRA4',
#   'MTRR',
#   'GSC',
#   'PARP2',
#   'TYSND1',
#   'LMX1A',
#   'MOK',
#   'ICK',
#   'ALX4',
#   'LMO1',
#   'PSEN1',
#   'LHX9',
#   'POR',
#   'LMO4',
#   'LMO3',
#   'RBPJL',
#   'HTRA1',
#   'ADRM1',
#   'ISL1',
#   'LHX2',
#   'LMO2',
#   'RICTOR',
#   'PSME4',
#   'LHX5',
#   'MAPKAP1',
#   'HTRA2',
#   'REL',
#   'LHX1',
#   'CSNK1G3',
#   'CSNK1G1',
#   'RBPJ',
#   'CSNK1G2',
#   'NOS1',
#   'UBFD1',
#   'PARP1',
#   'PSMD13',
#   'PSMD9',
#   'LTV1',
#   'PSMD3',
#   'NOS3',
#   'MLST8',
#   'NOS2',
#   'CMPK2'],
#  364: ['NAB1', 'HHEX', 'DGKE', 'TGIF2', 'SMARCD2'],
#  365: ['KLHL17', 'KLHL18', 'KLHL20', 'NR1H3', 'NR1H2', 'LHX5', 'LHX1'],
#  366: ['NYNRIN', 'MEIS3', 'ERAP2'],
#  376: ['AGRP', 'GHRHR', 'PTGIR', 'GHSR', 'MLNR', 'TBXA2R', 'NPY', 'PTGER3'],
#  382: ['C1QC',
#   'CX3CR1',
#   'MMP1',
#   'IL6',
#   'XCR1',
#   'CXCL6',
#   'CXCL5',
#   'CXCL3',
#   'CXCL2',
#   'CXCL1',
#   'CCR9',
#   'CXCR6',
#   'CCR10',
#   'CCR8',
#   'CCR6',
#   'CCR2',
#   'CCR7',
#   'CXCR3',
#   'CCR4',
#   'CXCR1',
#   'CCL5',
#   'CXCR5',
#   'CCR3',
#   'CXCR2',
#   'CCR1',
#   'CXCL10',
#   'CCR5',
#   'CXCR4',
#   'IL8'],
#  383: ['GAL', 'PLCD1', 'PLCB4', 'CCDC88B', 'PLCB2', 'PLCB3', 'PLCB1'],
#  386: ['ST6GALNAC1',
#   'MUC12',
#   'GCNT1',
#   'C1GALT1',
#   'C1GALT1C1',
#   'DPM1',
#   'SMAD4'],
#  398: ['PLCG1'],
#  401: ['MUC7', 'MUC5B'],
#  415: ['CD79A',
#   'CD79B',
#   'NGF',
#   'PIK3R5',
#   'NGFR',
#   'PRKCI',
#   'CBLB',
#   'PARD3',
#   'PIK3R3',
#   'PLCG2',
#   'SOCS3',
#   'PRKCZ',
#   'SH3KBP1',
#   'VAV2',
#   'VAV1',
#   'XIAP',
#   'TRAF2',
#   'SQSTM1',
#   'CBL',
#   'PDPK1',
#   'TRAF6',
#   'PLCG1',
#   'NCK1',
#   'NPM1'],
#  416: ['HPDL',
#   'ACY1',
#   'MAEA',
#   'RNMT',
#   'CBR1',
#   'AKR1B10',
#   'TSPO',
#   'POLH',
#   'POLI',
#   'ATG7',
#   'UBA3',
#   'PEPD',
#   'RNF40',
#   'UBA6',
#   'RSRC1',
#   'CYCS'],
#  417: ['MRPL10',
#   'TRIAP1',
#   'NDUFB3',
#   'MRPL55',
#   'MRPL18',
#   'NDUFB6',
#   'SLC25A10',
#   'UQCRQ',
#   'ATP5J2',
#   'UQCRB',
#   'NDUFB9',
#   'PTCD1',
#   'NDUFS6',
#   'ATP5L',
#   'NDUFS3',
#   'COX6A1P2',
#   'COX5A',
#   'ETFA',
#   'COX6A1',
#   'PMPCA',
#   'COX18',
#   'ATP5H',
#   'NDUFB10',
#   'ATP5G3',
#   'ATP5G1',
#   'VDAC2',
#   'OXA1L',
#   'SLC25A4',
#   'MRPL27',
#   'ATP5D',
#   'NDUFAB1',
#   'UQCRC2'],
#  418: ['STAMBPL1',
#   'MPND',
#   'STAMBP',
#   'BRCC3',
#   'ANAPC11',
#   'RNF7',
#   'UBA3',
#   'COPS6',
#   'PSMD14',
#   'UBA6',
#   'PSMD7'],
#  421: ['INPP5F',
#   'SH2D1B',
#   'INPP5E',
#   'INPP5J',
#   'INPP5K',
#   'FIG4',
#   'INPP5B',
#   'INPPL1',
#   'OCRL',
#   'INPP5D',
#   'ARF6',
#   'SACM1L'],
#  422: ['IGSF22',
#   'IGFN1',
#   'C9orf172',
#   'OBSL1',
#   'PLXNB3',
#   'SVEP1',
#   'PLXND1',
#   'PLXNA3',
#   'HGFAC',
#   'DLL3',
#   'EGFLAM',
#   'PLXNA4',
#   'CTNNAL1',
#   'PLXNA1',
#   'PLXNB1',
#   'DLL4',
#   'CTDSPL2',
#   'DLK1',
#   'MYLK',
#   'HMCN2',
#   'CTDSP2',
#   'EYS',
#   'CTDSPL',
#   'CTDSP1',
#   'VAV3',
#   'ENAH',
#   'CTDNEP1',
#   'MST1R',
#   'JAG1',
#   'CTNNA3',
#   'VASP',
#   'PARD6A',
#   'CTNNA2',
#   'TTN',
#   'DLK2',
#   'VAV1',
#   'VCL',
#   'PFN4',
#   'NDUFB10',
#   'CTNNA1',
#   'PFN2',
#   'TENC1',
#   'PFN1'],
#  423: ['KRT10',
#   'TMEM209',
#   'PFDN1',
#   'C20orf72',
#   'DEK',
#   'PHAX',
#   'CPSF4',
#   'DHCR24',
#   'ATAD3A',
#   'MAX',
#   'SRSF7',
#   'NUP43',
#   'SRSF3',
#   'U2AF1',
#   'SMN1',
#   'NUP62',
#   'SRSF2',
#   'DENR',
#   'SUB1',
#   'CFDP1',
#   'EXOSC3',
#   'PFDN2',
#   'EIF2A',
#   'POLDIP3',
#   'EXOSC6',
#   'PPIL3',
#   'RCC1',
#   'MYBBP1A',
#   'DHX30',
#   'EXOSC2',
#   'LSM1',
#   'TTC27',
#   'BUD31',
#   'LSM10',
#   'SNRPB2',
#   'SLC25A3',
#   'DHFR',
#   'LSM6',
#   'EIF1AY'],
#  424: ['TMEM30A', 'AP4B1', 'AP3B2', 'COPG1', 'AP3B1', 'MON2', 'AP2B1'],
#  426: ['PIGU',
#   'DOLK',
#   'GANC',
#   'MOGS',
#   'AGPAT1',
#   'PIGG',
#   'TMEM30C',
#   'GANAB',
#   'AGPAT2',
#   'TMEM30B',
#   'TMEM30A',
#   'TMED10',
#   'DDOST',
#   'PIGA',
#   'SYVN1'],
#  428: ['CBFA2T3',
#   'SSBP4',
#   'SSBP2',
#   'MED12L',
#   'TRIM33',
#   'SSBP3',
#   'MED13L',
#   'ATF6',
#   'MED13',
#   'MAP4K4',
#   'ATXN1',
#   'HESX1',
#   'TCF3',
#   'KDM5A',
#   'LMO4',
#   'PTPRF'],
#  429: ['CXorf56',
#   'GPATCH1',
#   'CCDC75',
#   'U2AF1L4',
#   'SREK1',
#   'MED11',
#   'PRPF18',
#   'CSDA',
#   'MEPCE',
#   'RBM8A',
#   'DNAJC17',
#   'CSTF1',
#   'DCUN1D1',
#   'SF1',
#   'UBL5',
#   'SRSF7',
#   'SNRNP40',
#   'SRSF3',
#   'TARDBP',
#   'GNB1L',
#   'HNRNPF',
#   'ABT1',
#   'SRSF2',
#   'ILF2',
#   'NARS',
#   'NUP153',
#   'TBL2',
#   'PCBP2',
#   'PARK2',
#   'COPS6',
#   'MYBBP1A',
#   'SUZ12',
#   'PRPF4',
#   'SMAD2',
#   'DAZ3',
#   'YBX1',
#   'NPM1',
#   'DAZ2',
#   'RBM3',
#   'LARP1',
#   'XRCC5',
#   'DAZ4'],
#  430: ['FAM136A',
#   'CPSF1',
#   'C7orf50',
#   'CDADC1',
#   'DCLRE1B',
#   'NOL12',
#   'DPH1',
#   'DCTD',
#   'CPSF3L',
#   'CTU2',
#   'SNX4',
#   'POLR3C',
#   'NOM1',
#   'SNX2',
#   'SNX1',
#   'GAMT',
#   'LAS1L',
#   'DNTTIP2',
#   'TEX10',
#   'UTP20',
#   'TEX13A',
#   'DUS1L',
#   'NOP9',
#   'WDR69',
#   'CECR1',
#   'TOMM40L',
#   'ADA',
#   'MDN1',
#   'EXOSC9',
#   'DPH5',
#   'NOA1',
#   'CDC23',
#   'ZNF593',
#   'TRMT2B',
#   'PUS7L',
#   'POLG2',
#   'RRP15',
#   'TRMT2A',
#   'FAM203B',
#   'C9orf114',
#   'ADAL',
#   'FAM203A',
#   'PUS7',
#   'FCF1',
#   'CPSF3',
#   'TRMT11',
#   'TOMM40',
#   'GARS',
#   'REXO4',
#   'WDR75',
#   'WDR4',
#   'ERCC4',
#   'DIEXF',
#   'RIOK2',
#   'IQCA1',
#   'ISG20L2',
#   'DDX31',
#   'AATF',
#   'SKIV2L',
#   'DDX55',
#   'DRG1',
#   'DHX34',
#   'PIAS2',
#   'UTP23',
#   'TRMT6',
#   'MYBBP1A',
#   'DHX40',
#   'DHX33',
#   'CIRH1A',
#   'FTSJ1',
#   'NOC4L',
#   'FIGN',
#   'UTP14C',
#   'METAP1D',
#   'BCCIP',
#   'FTSJ2',
#   'TRMT1L',
#   'ACTR6',
#   'DDX60',
#   'RBM28',
#   'NOL6',
#   'ISG20',
#   'TWISTNB',
#   'AEN',
#   'TTC27',
#   'WDR43',
#   'LYAR',
#   'METAP1',
#   'TRMT1',
#   'PAK1IP1',
#   'DDX49',
#   'FARSA',
#   'UTP14A',
#   'RBM19',
#   'SSBP1',
#   'NOP14',
#   'GNL1',
#   'DDX52',
#   'DDX28',
#   'SKIV2L2',
#   'DDX47',
#   'UTP6',
#   'SPAST',
#   'FANCM'],
#  431: ['PCBD1', 'PFKFB4', 'PFKFB3', 'PFKFB1', 'PFKFB2', 'CPSF3L', 'CPSF3'],
#  433: ['HMMR',
#   'FANCI',
#   'ARHGEF10L',
#   'CENPF',
#   'DLGAP5',
#   'CEP55',
#   'ATAD5',
#   'CDCA5',
#   'NCAPG',
#   'FANCD2',
#   'CLSPN',
#   'CDCA8',
#   'ZWILCH',
#   'NUF2',
#   'CDT1',
#   'DCK',
#   'UBE2C',
#   'ECT2',
#   'ARHGAP11A',
#   'CKS1B',
#   'CKS2',
#   'CDC45',
#   'PRC1',
#   'CCNE1',
#   'MCM9',
#   'RACGAP1',
#   'CDC25C',
#   'MCM8'],
#  434: ['GTPBP5', 'GTPBP10'],
#  436: ['THNSL1'],
#  437: ['GLTSCR2', 'EIF2A'],
#  440: ['CENPL',
#   'CENPM',
#   'SKA2',
#   'AHCTF1',
#   'CENPH',
#   'MLF1IP',
#   'ZWINT',
#   'CENPT',
#   'PHAX',
#   'BRCA2',
#   'MIS12',
#   'SPDL1',
#   'SPC24',
#   'CENPP',
#   'APITD1',
#   'CENPN',
#   'CENPK',
#   'STAG3',
#   'CASC5',
#   'CENPF',
#   'NDEL1',
#   'NDE1',
#   'RPA3',
#   'ATAD5',
#   'CDCA5',
#   'SGOL1',
#   'POLD2',
#   'RCC2',
#   'ZW10',
#   'CDCA8',
#   'CENPI',
#   'NUP155',
#   'STAG1',
#   'SLBP',
#   'STAG2',
#   'ESCO1',
#   'RPA4',
#   'KNTC1',
#   'ZWILCH',
#   'NCAPD2',
#   'CLIP1',
#   'POLA2',
#   'INCENP',
#   'ESCO2',
#   'NUF2',
#   'CLASP2',
#   'NEK6',
#   'CHTF18',
#   'RAE1',
#   'CLASP1',
#   'RNASEH2A',
#   'CDC45',
#   'SPO11',
#   'RPA2',
#   'RAD21L1'],
#  442: ['HPDL',
#   'HGD',
#   'SLC5A8',
#   'SLC5A6',
#   'SLC5A12',
#   'HPD',
#   'SLC5A5',
#   'SLC5A7',
#   'PRODH2',
#   'PRODH',
#   'THNSL2',
#   'PC',
#   'HOGA1',
#   'NPL',
#   'CNDP1',
#   'AGXT',
#   'ACSM2B',
#   'CNDP2',
#   'PGM5',
#   'DBT',
#   'PDHX',
#   'PGM1',
#   'DLAT',
#   'IDH2',
#   'DLST',
#   'IDH1',
#   'THNSL1',
#   'MLH1'],
#  444: ['POLR2D'],
#  445: ['CEP104',
#   'RSPH10B2',
#   'MORN3',
#   'RSPH10B',
#   'MORN1',
#   'ALS2CL',
#   'JPH4',
#   'RSPH1',
#   'MORN4',
#   'MORN5',
#   'JPH3',
#   'JPH1',
#   'JPH2',
#   'RNF8',
#   'EPT1',
#   'PLSCR5',
#   'ZDHHC20',
#   'ZDHHC15',
#   'CHPT1',
#   'CEPT1',
#   'KRT18',
#   'PLSCR2',
#   'ZDHHC2',
#   'PLSCR4',
#   'LMF1',
#   'SSNA1',
#   'PLSCR3',
#   'PLA2G15',
#   'ELOVL4',
#   'LCAT',
#   'TNFAIP6',
#   'RBM12B',
#   'RBM12',
#   'SCARF2',
#   'SCARF1',
#   'MEGF11',
#   'DKK2',
#   'PEAR1',
#   'SPNS3',
#   'MEGF6',
#   'SPNS2',
#   'MEGF10',
#   'CIAO1',
#   'SPNS1',
#   'PLSCR1',
#   'ALS2',
#   'DNAJC30',
#   'STX19',
#   'CTSD',
#   'KLHDC9',
#   'FBXO42',
#   'RABEPK',
#   'STX11',
#   'AKTIP',
#   'KLHDC1',
#   'KLHDC2',
#   'STX3',
#   'KLHDC3',
#   'STX4',
#   'STX2',
#   'KLHDC10',
#   'STX1B',
#   'CORO6',
#   'CORO2B',
#   'STX1A',
#   'CORO2A',
#   'CORO1B',
#   'CORO1C'],
#  447: ['ALG13',
#   'STT3A',
#   'N6AMT1',
#   'STT3B',
#   'SAR1A',
#   'CRLS1',
#   'CCS',
#   'DNAJC7',
#   'DNAJC24',
#   'DNAJC16',
#   'CDIPT',
#   'DNAJC22',
#   'DNAJB8',
#   'DNAJC18',
#   'DNAJB14',
#   'DNAJB7',
#   'COX18',
#   'DNAJB12',
#   'DNAJB2',
#   'SOD3',
#   'DHFRL1',
#   'DNAJB9',
#   'CANX',
#   'OXA1L',
#   'ATP5G2',
#   'DNAJA3',
#   'DNAJB13',
#   'DNAJB5',
#   'DNAJB6',
#   'DNAJB4',
#   'DHFR',
#   'MRPS11',
#   'STIP1'],
#  449: ['SLC16A11',
#   'SLC16A12',
#   'SLC16A6',
#   'SLC16A8',
#   'SLC16A10',
#   'SLC16A9',
#   'SLC16A5',
#   'SLC22A2',
#   'SLC16A1',
#   'GPX1',
#   'SLC30A2',
#   'SLC30A3',
#   'SLC30A8',
#   'PYCR2',
#   'MFSD3',
#   'SLC33A1',
#   'PYCR1',
#   'ATP7B',
#   'SCD5',
#   'MRPS14'],
#  450: ['PARD3B',
#   'LLGL2',
#   'GRASP',
#   'FRMPD2',
#   'VGLL2',
#   'IL16',
#   'LLGL1',
#   'RFNG',
#   'USH1C',
#   'LFNG',
#   'MFNG',
#   'GRID2IP',
#   'GRIP1',
#   'MPDZ',
#   'PRKCI',
#   'PARD3',
#   'LNX1',
#   'DLL1',
#   'NEURL',
#   'PRKCZ',
#   'NEURL1B',
#   'PDZD2',
#   'DLG5',
#   'RAE1',
#   'ISL1',
#   'MPP1',
#   'INADL',
#   'MPP4',
#   'MPP7',
#   'WNT7A',
#   'MAGI3',
#   'MPP5',
#   'MPP2',
#   'MPP6',
#   'MPP3',
#   'WNT7B',
#   'WNT2',
#   'WNT4',
#   'WNT5A',
#   'FPGT-TNNI3K'],
#  455: ['SPR',
#   'ZNF638',
#   'WBP11',
#   'BCLAF1',
#   'SAFB2',
#   'U2AF1L4',
#   'APBB1',
#   'HNRNPH2',
#   'S100A9',
#   'SAFB',
#   'GEMIN4',
#   'THRAP3',
#   'MLF1IP',
#   'USP39',
#   'AGMAT',
#   'SRRM3',
#   'DNAL4',
#   'NONO',
#   'SMU1',
#   'NUP50',
#   'SFPQ',
#   'DYNLL2',
#   'NFX1',
#   'HNRNPUL1',
#   'MEPCE',
#   'DDX46',
#   'TXNL4A',
#   'SF1',
#   'NUP160',
#   'LSM3',
#   'ZMAT2',
#   'HNRNPR',
#   'PAXIP1',
#   'SLU7',
#   'SNRPC',
#   'DDX23',
#   'HTATSF1',
#   'SAP18',
#   'ILF3',
#   'LSM7',
#   'TARDBP',
#   'STAU1',
#   'NAA38',
#   'HNRNPK',
#   'PTBP3',
#   'SMN1',
#   'HNRNPH1',
#   'WDR69',
#   'DYNLL1',
#   'SRRM2',
#   'RRP15',
#   'CPSF3',
#   'CRNKL1',
#   'NUP133',
#   'DHX29',
#   'XAB2',
#   'WDR48',
#   'UBR5',
#   'PCBP1',
#   'SART1',
#   'PRPF4',
#   'LSM1',
#   'LSM2',
#   'PRPF6',
#   'SNRNP200',
#   'YBX1',
#   'LSM10',
#   'SF3A1',
#   'PPIH',
#   'DHX16',
#   'UTP14A',
#   'BMI1',
#   'LSM6'],
#  456: ['CBLB', 'SHC1', 'CBL'],
#  458: ['TPH1',
#   'GGT6',
#   'GGT5',
#   'TH',
#   'QPRT',
#   'PAH',
#   'GGT7',
#   'GGT1',
#   'AGXT2L2',
#   'AGXT2L1',
#   'DCAF7',
#   'AGXT2',
#   'ABAT',
#   'STOML1',
#   'CNDP1',
#   'HAO2',
#   'AGXT',
#   'DDC',
#   'CNDP2',
#   'PGM5',
#   'GAD2',
#   'GOT1',
#   'GAD1',
#   'CARNS1',
#   'GOT2',
#   'ALDH16A1',
#   'ALDH1L2',
#   'PYGL',
#   'ALDH1L1',
#   'ALDH7A1',
#   'ALDH8A1',
#   'ALDH3B2',
#   'PGM1',
#   'IDH2',
#   'GLUL',
#   'ALDH3A1',
#   'EHHADH',
#   'ALDH1A2',
#   'ALDH9A1',
#   'ALDH3A2',
#   'ALDH2',
#   'ALDH1A3',
#   'ALDH1B1',
#   'IDH1',
#   'ALDH1A1',
#   'HADHA',
#   'SUCLG2'],
#  459: ['TAF11',
#   'PSMA8',
#   'WNT16',
#   'WNT5B',
#   'WNT7A',
#   'SOX2',
#   'WNT2B',
#   'WNT3',
#   'WNT7B',
#   'WNT2',
#   'WNT4',
#   'WNT5A',
#   'PSMD2',
#   'PSMA7'],
#  470: ['COX15',
#   'ABCG2',
#   'COX10',
#   'VPS13D',
#   'UGCG',
#   'HAS3',
#   'HAS2',
#   'HAS1',
#   'TAP2',
#   'ABCB10',
#   'ABCB9',
#   'ABCB8',
#   'TAP1',
#   'ABCC10',
#   'ABCC9',
#   'ABCC12',
#   'ABCC11',
#   'ABCC6',
#   'ABCC3',
#   'ABCC4',
#   'ABCB5',
#   'ABCC5',
#   'ABCC8',
#   'ABCC1',
#   'ABCB4',
#   'ABCC2',
#   'ABCB11',
#   'ABCB1'],
#  471: ['RPP40',
#   'ADAT3',
#   'TRDMT1',
#   'ADAT2',
#   'N6AMT1',
#   'DPH1',
#   'CTU1',
#   'GAMT',
#   'TRMT10A',
#   'ABT1',
#   'TRMT112',
#   'TRMT2B',
#   'TRMT2A',
#   'C9orf114',
#   'TRMT11',
#   'TRMT61B',
#   'EXOSC3',
#   'TRMT61A',
#   'DDX31',
#   'EXOSC6',
#   'UTP23',
#   'TRMT6',
#   'FTSJ1',
#   'NOC4L',
#   'EXOSC2',
#   'BCCIP',
#   'FTSJ2',
#   'TRMT1L',
#   'UTP11L',
#   'MPHOSPH10',
#   'LYAR',
#   'NOB1',
#   'TRMT1',
#   'DDX49',
#   'NOP14',
#   'DDX52',
#   'DDX28',
#   'EXOSC4',
#   'DDX47'],
#  472: ['THNSL1'],
#  473: ['SLC39A12',
#   'SLC39A5',
#   'SLC39A4',
#   'SLC39A8',
#   'SLC39A14',
#   'SLC39A10',
#   'SLC39A6',
#   'SLC39A13',
#   'SLC39A7',
#   'SLC39A11',
#   'PIGO',
#   'ATP7A',
#   'ATP7B',
#   'KIAA0317'],
#  474: ['VSX2',
#   'TCF21',
#   'CDON',
#   'NHLH1',
#   'CELSR3',
#   'PARD3B',
#   'ANGPT2',
#   'ASCL1',
#   'ANGPT1',
#   'VGLL2',
#   'ATOH7',
#   'PIWIL4',
#   'PBX4',
#   'GDF2',
#   'GBX1',
#   'HOXC5',
#   'GSX2',
#   'ATOH1',
#   'HOXD3',
#   'INHBC',
#   'GBX2',
#   'GSX1',
#   'BMP8A',
#   'GDF7',
#   'GDF1',
#   'PBX3',
#   'HOXA6',
#   'CHRD',
#   'HOXD1',
#   'GDF9',
#   'HOXB3',
#   'LEFTY1',
#   'HOXC6',
#   'HOXB8',
#   'HOXD8',
#   'BMP15',
#   'GDF6',
#   'BMP8B',
#   'INHBE',
#   'INHA',
#   'HOXB2',
#   'HOXD4',
#   'TDGF1',
#   'MEOX1',
#   'GDF15',
#   'NODAL',
#   'GDF3',
#   'BMP10',
#   'PBX2',
#   'GDF10',
#   'MMP9',
#   'HOXB1',
#   'HOXA3',
#   'TLE6',
#   'INHBB',
#   'HOXB4',
#   'HOXA2',
#   'HOXB6',
#   'HOXB5',
#   'MEIS3',
#   'HOXA4',
#   'BMP3',
#   'PKNOX2',
#   'AMH',
#   'HOXA7',
#   'HOXC8',
#   'HOXC4',
#   'GDF5',
#   'EN2',
#   'SFRP5',
#   'HOXB7',
#   'MMP2',
#   'LEFTY2',
#   'GDF11',
#   'PDX1',
#   'MNX1',
#   'INHBA',
#   'EN1',
#   'HOXA5',
#   'BMP5',
#   'PBX1',
#   'PKNOX1',
#   'FZD9',
#   'BMP6',
#   'E2F6',
#   'MSTN',
#   'TGIF1',
#   'ID2',
#   'FZD10',
#   'FZD8',
#   'MEIS2',
#   'FZD7',
#   'FZD3',
#   'FZD6',
#   'SFRP2',
#   'HOXA1',
#   'FRZB',
#   'TLE2',
#   'BMP7',
#   'TLE3',
#   'TLE4',
#   'MEOX2',
#   'SFRP1',
#   'FZD1',
#   'FZD5',
#   'FZD2',
#   'FZD4',
#   'TGFB3',
#   'E2F4',
#   'TGFB2',
#   'LNX1',
#   'EPN1',
#   'MEIS1',
#   'AES',
#   'BMP2',
#   'GSC2',
#   'E2F3',
#   'ISX',
#   'RHOXF1',
#   'ESX1',
#   'BMP4',
#   'SEBOX',
#   'RHOXF2B',
#   'DRGX',
#   'DPRX',
#   'NOBOX',
#   'ALX1',
#   'ALX3',
#   'RAX2',
#   'SHOX',
#   'PRRX2',
#   'DMBX1',
#   'SHOX2',
#   'OTP',
#   'TLE1',
#   'PROP1',
#   'RAX',
#   'PRRX1',
#   'LHX6',
#   'RHOXF2',
#   'UNCX',
#   'ISL2',
#   'HESX1',
#   'ARX',
#   'LHX8',
#   'HOPX',
#   'LMX1B',
#   'E2F1',
#   'GSC',
#   'LMX1A',
#   'ALX4',
#   'LMO1',
#   'SQSTM1',
#   'LHX9',
#   'CCNE2',
#   'LMO4',
#   'LMO3',
#   'WNT10A',
#   'ISL1',
#   'WNT6',
#   'LHX2',
#   'WNT8A',
#   'LMO2',
#   'WNT8B',
#   'LHX5',
#   'WNT9B',
#   'WNT9A',
#   'SEL1L',
#   'WNT16',
#   'TGFB1',
#   'LHX1',
#   'WNT5B',
#   'WNT11',
#   'DMD',
#   'CCNE1',
#   'WNT7A',
#   'WNT10B',
#   'MPP5',
#   'WNT2B',
#   'WNT3',
#   'UBR5',
#   'SUZ12',
#   'WNT7B',
#   'WNT2',
#   'MIB2',
#   'HECW1',
#   'WNT4',
#   'WNT5A'],
#  480: ['RALGDS', 'FBXW11'],
#  482: ['RPL41',
#   'UPF2',
#   'RPL28',
#   'RPL39',
#   'RPS21',
#   'RPL35A',
#   'RPL37',
#   'RPL34',
#   'RPS10',
#   'RPL29',
#   'RPS26',
#   'RPLP1',
#   'RPL21',
#   'RPL22',
#   'RPL32',
#   'RPS24',
#   'RPS27',
#   'RPS28',
#   'RPL31',
#   'RPL38',
#   'RPL36'],
#  485: ['STAMBPL1', 'STAMBP', 'BRCC3', 'COPS6'],
#  490: ['RNMT',
#   'GTF2E1',
#   'MYEF2',
#   'IFIH1',
#   'CBX3',
#   'PHF12',
#   'SRRM1',
#   'DDX19B',
#   'TRMT112',
#   'ZC3H15',
#   'XRCC5'],
#  492: ['SEC23IP',
#   'TP73',
#   'ATP13A5',
#   'ATP13A4',
#   'ATP13A3',
#   'EFNA4',
#   'EFNA1',
#   'MED21',
#   'ATP13A2',
#   'EFNB2',
#   'MMS19',
#   'PARP2',
#   'VPS35',
#   'ERCC2',
#   'PARP1',
#   'STAT3'],
#  494: ['PCGF1',
#   'DNMT3B',
#   'RNF170',
#   'RNF10',
#   'PDS5B',
#   'PDS5A',
#   'CDCA5',
#   'RPTN',
#   'AXIN1',
#   'RAD18',
#   'RARA',
#   'BIRC3',
#   'PAX6',
#   'RECQL5',
#   'SEPT14',
#   'SEPT10',
#   'SEPT8',
#   'NUP153',
#   'ERCC6L2',
#   'SEPT11',
#   'SEPT6',
#   'BTAF1',
#   'RECQL',
#   'BRCA1',
#   'NUP133',
#   'FBXO18',
#   'BLM',
#   'WRN',
#   'CDC16',
#   'KPNA7',
#   'ERCC5',
#   'IKBKG',
#   'ERCC6',
#   'EXO1'],
#  495: ['IST1', 'TSG101', 'HECTD3', 'KIAA0317', 'HECTD2'],
#  496: ['RBBP5',
#   'ING4',
#   'ING2',
#   'MSL3',
#   'ING3',
#   'ING5',
#   'ING1',
#   'BRWD1',
#   'BAZ1B',
#   'MORF4L2',
#   'BAZ2B',
#   'YEATS4'],
#  498: ['PCBP3',
#   'PCBP4',
#   'TARDBP',
#   'ZC3H14',
#   'TNPO2',
#   'TNPO1',
#   'PCBP2',
#   'SNRNP35',
#   'PABPC4L',
#   'PCBP1',
#   'PABPC5',
#   'DAZ3',
#   'DAZ2',
#   'RBM3',
#   'DAZ4'],
#  500: ['MAGIX',
#   'WWC2',
#   'WWC1',
#   'UBE3B',
#   'UBE3C',
#   'MAGI1',
#   'HECTD3',
#   'HECTD1',
#   'KIAA0317',
#   'MAGI3',
#   'HECTD2',
#   'UBR5',
#   'HECW1'],
#  501: ['ZFAND3',
#   'ZFAND6',
#   'RABEP1',
#   'ZFAND5',
#   'KCTD7',
#   'ARHGAP1',
#   'RABGEF1',
#   'SGSM2',
#   'TBC1D13',
#   'TBC1D16',
#   'SGSM1',
#   'TBC1D28',
#   'TBC1D3G',
#   'TBC1D3F',
#   'TBC1D3C',
#   'TBC1D26',
#   'SGSM3',
#   'TBC1D3H',
#   'TBC1D3B',
#   'TBC1D29',
#   'TBC1D8B',
#   'TBC1D9B',
#   'TBC1D8',
#   'TBC1D14',
#   'TBC1D12',
#   'TBC1D3',
#   'TBC1D21',
#   'TBC1D9',
#   'TBC1D25',
#   'RABGAP1L',
#   'TBC1D17',
#   'RABGAP1',
#   'USP6NL',
#   'TBC1D15',
#   'RALBP1',
#   'RABL6',
#   'RAB19',
#   'OCRL',
#   'RAB43',
#   'RAB33A',
#   'RAB33B',
#   'TBC1D30',
#   'GRTP1',
#   'TBC1D2',
#   'USP6',
#   'TBC1D2B',
#   'RAB1B',
#   'GDI2',
#   'RAB1A',
#   'CFL2',
#   'RAB13',
#   'PFN1',
#   'VAMP7',
#   'RAB10'],
#  502: ['CATSPER4',
#   'KCNK16',
#   'KCNK7',
#   'KCND1',
#   'KCNK6',
#   'KCNK18',
#   'KCNK5',
#   'KCNK17',
#   'COQ10B',
#   'KCNK10',
#   'KCNK4',
#   'KCNS2',
#   'KCNK2',
#   'KCNV2',
#   'KCNG3',
#   'KCNV1',
#   'KCNS1',
#   'KCNK1',
#   'KCNG4',
#   'KCNQ5',
#   'CACNA1I',
#   'KCNC3',
#   'KCNB2',
#   'KCNQ4',
#   'KCNC4',
#   'CACNA1H',
#   'KCNG2',
#   'KCNG1',
#   'KCNC2',
#   'KCNF1',
#   'KCNA7',
#   'KCNS3',
#   'KCNC1',
#   'KCNA10',
#   'KCNQ3',
#   'KCNA6',
#   'KCNQ2',
#   'SCN4A',
#   'KCND3',
#   'SCN2A',
#   'SCN1A',
#   'KCND2',
#   'KCNA1',
#   'SLC20A2',
#   'KCNA3',
#   'KCNB1',
#   'KCNA4',
#   'SLC20A1',
#   'GDPD4',
#   'GDPD2',
#   'PARL',
#   'KCNQ1',
#   'KCNA5',
#   'GDPD5',
#   'GDPD3',
#   'GDPD1',
#   'KCNA2',
#   'RHBDF2',
#   'GDE1',
#   'FHIT',
#   'DCTD',
#   'SLC9A3',
#   'SLC9A6',
#   'SLC9A7',
#   'SLC9A9',
#   'SLC9C1',
#   'GPCPD1',
#   'UROD',
#   'SLC9A8',
#   'ALDH5A1',
#   'ACO1',
#   'IREB2',
#   'HINT2',
#   'PPCS',
#   'GPD1L',
#   'PGM2',
#   'UBE2H',
#   'GPD1',
#   'PPCDC',
#   'GLUD1',
#   'LDHC',
#   'HINT1',
#   'UBA6'],
#  503: ['AGK',
#   'CERK',
#   'CERKL',
#   'RTDR1',
#   'ARMC4',
#   'SPHK2',
#   'SPHK1',
#   'CSNK1G3',
#   'CSNK1G1',
#   'CSNK1G2',
#   'TSNARE1',
#   'STX16-NPEPL1',
#   'STX17',
#   'STX16'],
#  508: ['TCP11L1',
#   'PEX6',
#   'POP4',
#   'ARHGEF2',
#   'NTHL1',
#   'IQCA1',
#   'PEX1',
#   'FIGN',
#   'PAF1',
#   'FIGNL1',
#   'ATAD1',
#   'SPAST'],
#  509: ['PARD3B',
#   'LLGL2',
#   'GRASP',
#   'FRMPD2',
#   'VGLL2',
#   'ADAM17',
#   'IL16',
#   'LLGL1',
#   'RFNG',
#   'USH1C',
#   'LFNG',
#   'MFNG',
#   'GRID2IP',
#   'ADAM10',
#   'GRIP1',
#   'MPDZ',
#   'PRKCI',
#   'PARD3',
#   'FZD7',
#   'SFRP2',
#   'FRZB',
#   'SFRP1',
#   'FZD1',
#   'FZD5',
#   'FZD2',
#   'LNX1',
#   'DLL1',
#   'NEURL',
#   'PRKCZ',
#   'NEURL1B',
#   'UNCX',
#   'LMX1B',
#   'PDZD2',
#   'LMX1A',
#   'DLG5',
#   'RAE1',
#   'ISL1',
#   'WNT6',
#   'LHX2',
#   'WNT8A',
#   'LMO2',
#   'MPP1',
#   'INADL',
#   'MPP4',
#   'LHX1',
#   'MPP7',
#   'WNT11',
#   'MAGI3',
#   'MPP5',
#   'MPP2',
#   'WNT2B',
#   'WNT3',
#   'MPP6',
#   'MPP3',
#   'WNT2',
#   'WNT4',
#   'WNT5A',
#   'FPGT-TNNI3K'],
#  510: ['NOL7',
#   'PSMG2',
#   'PTMA',
#   'TRMT12',
#   'PARP9',
#   'TRDMT1',
#   'ADAT2',
#   'USP50',
#   'USP29',
#   'USP26',
#   'SHFM1',
#   'USP37',
#   'IRF7',
#   'SRP68',
#   'TMEM189',
#   'USP43',
#   'TRMT10B',
#   'UFD1L',
#   'PSMB9',
#   'USP21',
#   'USP8',
#   'TRMT10A',
#   'PSEN2',
#   'DNMT1',
#   'USP2',
#   'IGBP1',
#   'HINT2',
#   'PSMB8',
#   'PSMB6',
#   'PSME3',
#   'NEDD8-MDP1',
#   'PSEN1',
#   'ISY1-RAB43',
#   'C12orf10',
#   'VCL',
#   'ISY1',
#   'ALG1L',
#   'ADRM1',
#   'UBE2V2',
#   'HECTD1',
#   'C9orf114',
#   'PSMD8',
#   'ALG11',
#   'ALG1',
#   'PSMD11',
#   'PSMA8',
#   'UBE2V1',
#   'PSMB3',
#   'ALG2',
#   'PSMA6',
#   'GARS',
#   'KIAA0141',
#   'PSMB5',
#   'PIGA',
#   'PSMD1',
#   'PSMA2',
#   'PDHB',
#   'WASL',
#   'EXOSC2',
#   'TRMT1L',
#   'HECW1',
#   'HINT1',
#   'ISG20',
#   'PSMB4',
#   'PSMB7',
#   'PSMB10',
#   'PSMD14',
#   'PSMD13',
#   'STAT1',
#   'TRMT1',
#   'PSMA3',
#   'PSMD2',
#   'PSMD12',
#   'PSMA7',
#   'PSMD7',
#   'PSMD3',
#   'EXOSC5',
#   'UTP6',
#   'STAT3'],
#  512: ['TOR1B',
#   'ALG8',
#   'ALG6',
#   'PGAP1',
#   'ISCA1',
#   'ESD',
#   'ERLEC1',
#   'ISCA2',
#   'CARKD',
#   'YJEFN3',
#   'DNAJC1',
#   'APOA1BP',
#   'OS9',
#   'SLC9B1P1',
#   'TMBIM1',
#   'AGL',
#   'DNAJC12',
#   'SLC9B1',
#   'SLC9B2',
#   'DERL3',
#   'CLPX',
#   'DERL2',
#   'SLC9A5',
#   'TUSC3',
#   'MAGT1',
#   'SLC9A4',
#   'DNAJC17',
#   'FAF2',
#   'SLC9A2',
#   'SLC9A3',
#   'DERL1',
#   'SLC9A6',
#   'RNFT2',
#   'SLC9A7',
#   'SLC9A9',
#   'SLC9C1',
#   'SLC9A8',
#   'MBTPS1',
#   'ALDH5A1',
#   'LNPEP',
#   'GMPPB',
#   'SLC9A1',
#   'GGA3',
#   'GGA2',
#   'GGA1',
#   'SLC9C2',
#   'REN',
#   'RNFT1',
#   'DNAJC24',
#   'SEC14L1',
#   'DNAJC16',
#   'DNAJC22',
#   'DNAJC5',
#   'DNAJB8',
#   'B3GNTL1',
#   'EXOC5',
#   'DNAJC18',
#   'DNAJB14',
#   'DNAJB7',
#   'CTSD',
#   'ALG5',
#   'DNAJB12',
#   'RNF145',
#   'DNAJB2',
#   'DDOST',
#   'RNF139',
#   'DNAJB9',
#   'ALDH3A2',
#   'PIGA',
#   'DNAJA3',
#   'DPM1',
#   'GBE1',
#   'DNAJB13',
#   'DNAJB5',
#   'DNAJB6',
#   'DNAJB4',
#   'CHFR',
#   'AMFR',
#   'SYVN1',
#   'ATAD1'],
#  514: ['FN3K',
#   'FN3KRP',
#   'CAPNS2',
#   'GCA',
#   'SDR39U1',
#   'PEF1',
#   'SRI',
#   'PYROXD2',
#   'CLIC2',
#   'CLIC6',
#   'PDCD6',
#   'CLIC5',
#   'CAPNS1',
#   'CLIC4',
#   'RETSAT',
#   'SLC20A2',
#   'ABCD4',
#   'SLC20A1',
#   'PDXP',
#   'PGP',
#   'HDHD1',
#   'CTNNBL1',
#   'NANOS2',
#   'NANOS3',
#   'NANOS1',
#   'AK7',
#   'AMT',
#   'AK3',
#   'HAT1',
#   'AK8',
#   'AKD1',
#   'KDM5D',
#   'AK4',
#   'KDM5C',
#   'KDM5A',
#   'AK2',
#   'UBE2H',
#   'KDM5B',
#   'GUF1',
#   'RPE'],
#  515: ['PGM3'],
#  517: ['UNC119', 'IGFN1', 'OBSL1', 'PKP4', 'RACGAP1', 'ERCC2']}

# %%
# use functions to print info to files: (annoying, but need to get info into format used for funcE package)


# 1) a background protein list to be used for functional enrichment analysis
background_proteins_filepath = "data/ic_50/background_proteinlist.txt"
print_protein_background_to_file(matrix, background_proteins_filepath)

# %%
# 2) file containing protein to go term
term_mapping_filepath = "data/ic_50/term_mapping.txt"
create_term_mapping_list("demo_data/dream3_go_results.tsv", term_mapping_filepath)

# 3) not a file, but need to establish a background of all GO terms! (to be used for functional enrichment analysis)
background_go_terms = vocabs.getTerms(['GO'])

# %%
# continue printing info to files to be used in functional enrichment analysis:

# 4) print original clusters to a file
og_query_filepath = 'demo_data/original_clusters.txt'
print_querylist_of_clusters_to_file(clusters, clusters.get_all_cluster_labels(),og_query_filepath)

# 5) print updated clusters to a file (just append the function to include the dictionary of qualifying proteins)
updated_query_filepath = 'demo_data/updated_clusters.txt'
print_querylist_of_clusters_to_file(clusters, clusters.get_all_cluster_labels(), updated_query_filepath, qualifying_proteins)

# %%
original_fe = get_initialized_fe(background_proteins_filepath, term_mapping_filepath, termlist = background_go_terms)

original_fe.importFiles({'query': og_query_filepath })
original_fe.run(cluster=False)

# %%
# do functional enrichment on updated clusters!!

updated_fe_all_proteins = get_initialized_fe(background_proteins_filepath, term_mapping_filepath, termlist = background_go_terms)

updated_fe_all_proteins.importFiles({'query': updated_query_filepath })
updated_fe_all_proteins.run(cluster=False)

# %%
# print data by the numbers!
print(f"number of clusters that were updated with proteins: {len(qualifying_proteins.keys())}\n")

# clusters that are functionally enriched
print(f"number of functionally enriched clusters (modules) out of {len(qualifying_proteins.keys())} original clusters: {original_fe.enrichment['Module'].nunique()}")
print(f"number of functionally enriched clusters after addition of all proteins: {updated_fe_all_proteins.enrichment['Module'].nunique()}")

print(f"")


# significant P-values!!!
print(f"number of significant pvals in original clusters before updating: {original_fe.enrichment['Fishers_pvalue'].count()}")
print(f"number of significant pvals in clusters with all proteins added: {updated_fe_all_proteins.enrichment['Fishers_pvalue'].count()}")
# Out:
# number of clusters that were updated with proteins: 12
#
# number of functionally enriched clusters (modules) out of 12 original clusters: 155
# number of functionally enriched clusters after addition of all proteins: 155
#
# number of significant pvals in original clusters before updating: 405
# number of significant pvals in clusters with all proteins added: 411
